# %% [markdown]
# !['평가 기준'](ref.png)

# %% [markdown]
# ### EDA, 탐색적 데이터 분석

# %% [markdown]
# > 필요 라이브러리 import

# %%
import pandas as pd
import os 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
os.chdir('C:/Users/mlosv/Downloads/23.08.22 데이터분석경진대회')

# %%
# CSV 파일 경로 지정
file_name = 'loan_customer.csv'

# %%
# CSV 파일 읽기
df = pd.read_csv(file_name)

# %%
# 컬럼 정보 미리 붙여 보기 (지주 제공 ppt참고)
column_info = {'SK_ID_CURR':'대출식별번호',
'NAME_CONTRACT_TYPE':'계약유형',
'CODE_GENDER':'성별',
'FLAG_OWN_REALTY':'자가부동산보유여부',
'CNT_CHILDREN':'자녀수',
'AMT_INCOME_TOTAL':'소득금액(USD)',
'AMT_CREDIT':'신용대출금액(USD)',
'NAME_INCOME_TYPE':'소득유형',
'NAME_EDUCATION_TYPE':'학력',
'NAME_FAMILY_STATUS':'결혼상태',
'NAME_HOUSING_TYPE':'주거형태',
'REGION_POPULATION_RELATIVE':'거주지역의표준화된인구',
'DAYS_BIRTH':'대출신청시점에서의일단위나이(기준시점대비상대적인시간)',
'DAYS_EMPLOYED':'대출신청시점에서의고객의근무일수(기준시점대비상대적인시간)',
'DAYS_REGISTRATION':'대출신청이전에고객이등록정보를변경한시점사이의일수(기준시점대비상대적인시간)',
'DAYS_ID_PUBLISH':'대출신청이전에고객이신분증을변경한시점사이의일수(기준시점대비상대적인시간)',
'FLAG_MOBIL':'휴대폰번호등록여부',
'FLAG_EMP_PHONE':'고용주연락처등록여부',
'FLAG_WORK_PHONE':'직장전화번호등록여부',
'FLAG_PHONE':'집전화번호등록여부',
'FLAG_EMAIL':'이메일주소등록여부',
'REGION_RATING_CLIENT':'거주지등급',
'WEEKDAY_APPR_PROCESS_START':'대출신청요일',
'HOUR_APPR_PROCESS_START':'대출신청시간대',
'REG_CITY_NOT_LIVE_CITY':'고객의등록지주소와실거주지일치여부',
'REG_CITY_NOT_WORK_CITY':'고객의등록지주소와직장주소일치여부',
'LIVE_CITY_NOT_WORK_CITY':'고객의실거주지와직장주소일치여부',
'ORGANIZATION_TYPE':'근무회사유형',
'FLAG_DOCUMENT_2':'문서2제공여부',
'FLAG_DOCUMENT_3':'문서3제공여부',
'FLAG_DOCUMENT_4':'문서4제공여부',
'CB_SCORE_1':'신용점수1',
'CB_SCORE_2':'신용점수2',
'CB_SCORE_3':'신용점수3',
'TARGET':'연체여부'}

# %%
# 컬럼 정보 수정 
df_v2 = df.copy() 

for col in df_v2.columns : 
    df_v2.rename(columns = {col:column_info[col]}, inplace = True)
    print(col+'컬럼의 이름을 '+column_info[col]+'로 수정했습니다 ')
# Out:
# SK_ID_CURR컬럼의 이름을 대출식별번호로 수정했습니다
# NAME_CONTRACT_TYPE컬럼의 이름을 계약유형로 수정했습니다
# CODE_GENDER컬럼의 이름을 성별로 수정했습니다
# FLAG_OWN_REALTY컬럼의 이름을 자가부동산보유여부로 수정했습니다
# CNT_CHILDREN컬럼의 이름을 자녀수로 수정했습니다
# AMT_INCOME_TOTAL컬럼의 이름을 소득금액(USD)로 수정했습니다
# AMT_CREDIT컬럼의 이름을 신용대출금액(USD)로 수정했습니다
# NAME_INCOME_TYPE컬럼의 이름을 소득유형로 수정했습니다
# NAME_EDUCATION_TYPE컬럼의 이름을 학력로 수정했습니다
# NAME_FAMILY_STATUS컬럼의 이름을 결혼상태로 수정했습니다
# NAME_HOUSING_TYPE컬럼의 이름을 주거형태로 수정했습니다
# REGION_POPULATION_RELATIVE컬럼의 이름을 거주지역의표준화된인구로 수정했습니다
# DAYS_BIRTH컬럼의 이름을 대출신청시점에서의일단위나이(기준시점대비상대적인시간)로 수정했습니다
# DAYS_EMPLOYED컬럼의 이름을 대출신청시점에서의고객의근무일수(기준시점대비상대적인시간)로 수정했습니다
# DAYS_REGISTRATION컬럼의 이름을 대출신청이전에고객이등록정보를변경한시점사이의일수(기준시점대비상대적인시간)로 수정했습니다
# DAYS_ID_PUBLISH컬럼의 이름을 대출신청이전에고객이신분증을변경한시점사이의일수(기준시점대비상대적인시간)로 수정했습니다
# FLAG_MOBIL컬럼의 이름을 휴대폰번호등록여부로 수정했습니다
# FLAG_EMP_PHONE컬럼의 이름을 고용주연락처등록여부로 수정했습니다
# FLAG_WORK_PHONE컬럼의 이름을 직장전화번호등록여부로 수정했습니다
# FLAG_PHONE컬럼의 이름을 집전화번호등록여부로 수정했습니다
# FLAG_EMAIL컬럼의 이름을 이메일주소등록여부로 수정했습니다
# REGION_RATING_CLIENT컬럼의 이름을 거주지등급로 수정했습니다
# WEEKDAY_APPR_PROCESS_START컬럼의 이름을 대출신청요일로 수정했습니다
# HOUR_APPR_PROCESS_START컬럼의 이름을 대출신청시간대로 수정했습니다
# REG_CITY_NOT_LIVE_CITY컬럼의 이름을 고객의등록지주소와실거주지일치여부로 수정했습니다
# REG_CITY_NOT_WORK_CITY컬럼의 이름을 고객의등록지주소와직장주소일치여부로 수정했습니다
# LIVE_CITY_NOT_WORK_CITY컬럼의 이름을 고객의실거주지와직장주소일치여부로 수정했습니다
# ORGANIZATION_TYPE컬럼의 이름을 근무회사유형로 수정했습니다
# FLAG_DOCUMENT_2컬럼의 이름을 문서2제공여부로 수정했습니다
# FLAG_DOCUMENT_3컬럼의 이름을 문서3제공여부로 수정했습니다
# FLAG_DOCUMENT_4컬럼의 이름을 문서4제공여부로 수정했습니다
# CB_SCORE_1컬럼의 이름을 신용점수1로 수정했습니다
# CB_SCORE_2컬럼의 이름을 신용점수2로 수정했습니다
# CB_SCORE_3컬럼의 이름을 신용점수3로 수정했습니다
# TARGET컬럼의 이름을 연체여부로 수정했습니다

# %% [markdown]
# > 전체 데이터 구조 요약해서 보기

# %%
df.head()
# Out:
#    SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0      100002         Cash loans           M               Y             0
# 1      100004    Revolving loans         NaN             NaN             0
# 2      100020         Cash loans           M               N             0
# 3      100029         Cash loans           M               N             2
# 4      100048         Cash loans         NaN               Y             0
#
#    AMT_INCOME_TOTAL  AMT_CREDIT NAME_INCOME_TYPE  \
# 0          202500.0         NaN          Working
# 1           67500.0    135000.0          Working
# 2          108000.0    509602.5          Working
# 3          135000.0         NaN          Working
# 4          202500.0    604152.0          Working
#
#              NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  ...  \
# 0  Secondary / secondary special  Single / not married  ...
# 1  Secondary / secondary special  Single / not married  ...
# 2  Secondary / secondary special               Married  ...
# 3  Secondary / secondary special               Married  ...
# 4  Secondary / secondary special               Married  ...
#
#   REG_CITY_NOT_WORK_CITY  LIVE_CITY_NOT_WORK_CITY       ORGANIZATION_TYPE  \
# 0                      0                        0  Business Entity Type 3
# 1                      0                        0              Government
# 2                      1                        0              Government
# 3                      1                        1  Business Entity Type 3
# 4                      1                        1        Industry: type 1
#
#    FLAG_DOCUMENT_2  FLAG_DOCUMENT_3  FLAG_DOCUMENT_4  CB_SCORE_1  CB_SCORE_2  \
# 0                0                1                0         NaN         NaN
# 1                0                0                0   26.499494   57.600542
# 2                0                1                0         NaN   63.496369
# 3                0                1                0   82.376245   45.996152
# 4                0                1                0   66.199985         NaN
#
#    CB_SCORE_3  TARGET
# 0   58.349224       1
# 1   46.433666       0
# 2         NaN       0
# 3   68.694333       0
# 4         NaN       0
#
# [5 rows x 35 columns]

# %% [markdown]
# *1.1 Check Point → 대출식별번호에 중복 없나*

# %%
# 대출식별 기준으로 그룹화하고 counting
grouped = df.groupby('SK_ID_CURR').size()

# counting이 1 넘어간 것들만 필터링
filtered_grouped = grouped[grouped > 1]

print(filtered_grouped)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# *1.1 결과→ 대출일련번호가 unique key. 그럼 고객 구분은(고객:대출 = 1:n 관계)은 어떻게 하나?*

# %% [markdown]
# *1.2 Check Point → 수치/범주형 변수들 타입이 바르게 들어갔나 ?*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24000 entries, 0 to 23999
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   SK_ID_CURR                  24000 non-null  int64
#  1   NAME_CONTRACT_TYPE          24000 non-null  object
#  2   CODE_GENDER                 16906 non-null  object
#  3   FLAG_OWN_REALTY             14429 non-null  object
#  4   CNT_CHILDREN                24000 non-null  int64
#  5   AMT_INCOME_TOTAL            24000 non-null  float64
#  6   AMT_CREDIT                  16700 non-null  float64
#  7   NAME_INCOME_TYPE            24000 non-null  object
#  8   NAME_EDUCATION_TYPE         24000 non-null  object
#  9   NAME_FAMILY_STATUS          24000 non-null  object
#  10  NAME_HOUSING_TYPE           24000 non-null  object
#  11  REGION_POPULATION_RELATIVE  16851 non-null  float64
#  12  DAYS_BIRTH                  19251 non-null  float64
#  13  DAYS_EMPLOYED               16851 non-null  float64
#  14  DAYS_REGISTRATION           14267 non-null  float64
#  15  DAYS_ID_PUBLISH             19259 non-null  float64
#  16  FLAG_MOBIL                  24000 non-null  int64
#  17  FLAG_EMP_PHONE              24000 non-null  int64
#  18  FLAG_WORK_PHONE             24000 non-null  int64
#  19  FLAG_PHONE                  24000 non-null  int64
#  20  FLAG_EMAIL                  24000 non-null  int64
#  21  REGION_RATING_CLIENT        24000 non-null  int64
#  22  WEEKDAY_APPR_PROCESS_START  24000 non-null  object
#  23  HOUR_APPR_PROCESS_START     24000 non-null  int64
#  24  REG_CITY_NOT_LIVE_CITY      24000 non-null  int64
#  25  REG_CITY_NOT_WORK_CITY      24000 non-null  int64
#  26  LIVE_CITY_NOT_WORK_CITY     24000 non-null  int64
#  27  ORGANIZATION_TYPE           24000 non-null  object
#  28  FLAG_DOCUMENT_2             24000 non-null  int64
#  29  FLAG_DOCUMENT_3             24000 non-null  int64
#  30  FLAG_DOCUMENT_4             24000 non-null  int64
#  31  CB_SCORE_1                  17854 non-null  float64
#  32  CB_SCORE_2                  15726 non-null  float64
#  33  CB_SCORE_3                  16892 non-null  float64
#  34  TARGET                      24000 non-null  int64
# dtypes: float64(10), int64(16), object(9)
# memory usage: 6.4+ MB

# %% [markdown]
# *1.2 결과→ 수치형 변수는 float/int, 범주형 변수는 object로 잘 들어가있음*

# %% [markdown]
# *1.3 Check Point → 결측값이 어떻게 들어가있는지 모르니, 결측치 유효값들 살펴보기 위해 value_coutns*

# %%
for column in df.columns:
    value_counts = df[column].value_counts(dropna = False)
    print(f"Value counts for {column} {column_info[column]}:\n{value_counts}\n")
# Out:
# Value counts for SK_ID_CURR 대출식별번호:
# 100002    1
# 337229    1
# 337317    1
# 337293    1
# 337288    1
#          ..
# 218660    1
# 218625    1
# 218609    1
# 218594    1
# 456228    1
# Name: SK_ID_CURR, Length: 24000, dtype: int64
#
# Value counts for NAME_CONTRACT_TYPE 계약유형:
# Cash loans         21733
# Revolving loans     2267
# Name: NAME_CONTRACT_TYPE, dtype: int64
#
# Value counts for CODE_GENDER 성별:
# F      11211
# NaN     7094
# M       5694
# XNA        1
# Name: CODE_GENDER, dtype: int64
#
# Value counts for FLAG_OWN_REALTY 자가부동산보유여부:
# Y      9939
# NaN    9571
# N      4490
# Name: FLAG_OWN_REALTY, dtype: int64
#
# Value counts for CNT_CHILDREN 자녀수:
# 0    16859
# 1     4703
# 2     2046
# 3      341
# 4       41
# 5        9
# 7        1
# Name: CNT_CHILDREN, dtype: int64
#
# Value counts for AMT_INCOME_TOTAL 소득금액(USD):
# 135000.0    2779
# 112500.0    2422
# 157500.0    2052
# 180000.0    1860
# 90000.0     1785
#             ...
# 68400.0        1
# 118800.0       1
# 183375.0       1
# 113008.5       1
# 120784.5       1
# Name: AMT_INCOME_TOTAL, Length: 494, dtype: int64
#
# Value counts for AMT_CREDIT 신용대출금액(USD):
# NaN          7300
# 450000.0      567
# 675000.0      493
# 225000.0      410
# 180000.0      403
#              ...
# 1416825.0       1
# 494118.0        1
# 1665000.0       1
# 451647.0        1
# 995643.0        1
# Name: AMT_CREDIT, Length: 2267, dtype: int64
#
# Value counts for NAME_INCOME_TYPE 소득유형:
# Working                 12460
# Commercial associate     5527
# Pensioner                4294
# State servant            1714
# Student                     2
# Maternity leave             2
# Businessman                 1
# Name: NAME_INCOME_TYPE, dtype: int64
#
# Value counts for NAME_EDUCATION_TYPE 학력:
# Secondary / secondary special    17054
# Higher education                  5857
# Incomplete higher                  796
# Lower secondary                    278
# Academic degree                     15
# Name: NAME_EDUCATION_TYPE, dtype: int64
#
# Value counts for NAME_FAMILY_STATUS 결혼상태:
# Married                 15275
# Single / not married     3557
# Civil marriage           2336
# Separated                1527
# Widow                    1304
# Unknown                     1
# Name: NAME_FAMILY_STATUS, dtype: int64
#
# Value counts for NAME_HOUSING_TYPE 주거형태:
# House / apartment      21213
# With parents            1206
# Municipal apartment      911
# Rented apartment         391
# Office apartment         203
# Co-op apartment           76
# Name: NAME_HOUSING_TYPE, dtype: int64
#
# Value counts for REGION_POPULATION_RELATIVE 거주지역의표준화된인구:
# NaN         7149
# 0.035792     893
# 0.046220     734
# 0.030755     656
# 0.026392     641
#             ...
# 0.001417      26
# 0.001333      11
# 0.000938       2
# 0.000533       1
# 0.000290       1
# Name: REGION_POPULATION_RELATIVE, Length: 82, dtype: int64
#
# Value counts for DAYS_BIRTH 대출신청시점에서의일단위나이(기준시점대비상대적인시간):
#  NaN        4749
# -17329.0       8
# -15961.0       7
# -21878.0       7
# -12846.0       7
#             ...
# -24266.0       1
# -18568.0       1
# -21506.0       1
# -11377.0       1
# -12847.0       1
# Name: DAYS_BIRTH, Length: 11222, dtype: int64
#
# Value counts for DAYS_EMPLOYED 대출신청시점에서의고객의근무일수(기준시점대비상대적인시간):
#  NaN         7149
#  365243.0    2999
# -222.0         14
# -212.0         13
# -147.0         13
#              ...
# -7274.0         1
# -4962.0         1
# -7087.0         1
# -4107.0         1
# -5168.0         1
# Name: DAYS_EMPLOYED, Length: 5431, dtype: int64
#
# Value counts for DAYS_REGISTRATION 대출신청이전에고객이등록정보를변경한시점사이의일수(기준시점대비상대적인시간):
#  NaN        9733
# -610.0         9
# -3402.0        8
# -2744.0        7
# -4514.0        7
#             ...
# -5250.0        1
# -6852.0        1
# -13504.0       1
# -9551.0        1
# -2970.0        1
# Name: DAYS_REGISTRATION, Length: 8207, dtype: int64
#
# Value counts for DAYS_ID_PUBLISH 대출신청이전에고객이신분증을변경한시점사이의일수(기준시점대비상대적인시간):
#  NaN       4741
# -4073.0      19
# -4053.0      18
# -4512.0      16
# -4008.0      16
#            ...
# -963.0        1
# -6126.0       1
# -3544.0       1
# -478.0        1
# -3747.0       1
# Name: DAYS_ID_PUBLISH, Length: 5247, dtype: int64
#
# Value counts for FLAG_MOBIL 휴대폰번호등록여부:
# 1    24000
# Name: FLAG_MOBIL, dtype: int64
#
# Value counts for FLAG_EMP_PHONE 고용주연락처등록여부:
# 1    19706
# 0     4294
# Name: FLAG_EMP_PHONE, dtype: int64
#
# Value counts for FLAG_WORK_PHONE 직장전화번호등록여부:
# 0    19112
# 1     4888
# Name: FLAG_WORK_PHONE, dtype: int64
#
# Value counts for FLAG_PHONE 집전화번호등록여부:
# 0    17276
# 1     6724
# Name: FLAG_PHONE, dtype: int64
#
# Value counts for FLAG_EMAIL 이메일주소등록여부:
# 0    22674
# 1     1326
# Name: FLAG_EMAIL, dtype: int64
#
# Value counts for REGION_RATING_CLIENT 거주지등급:
# 2    17656
# 3     3794
# 1     2550
# Name: REGION_RATING_CLIENT, dtype: int64
#
# Value counts for WEEKDAY_APPR_PROCESS_START 대출신청요일:
# TUESDAY      4135
# WEDNESDAY    4071
# FRIDAY       3995
# MONDAY       3977
# THURSDAY     3843
# SATURDAY     2592
# SUNDAY       1387
# Name: WEEKDAY_APPR_PROCESS_START, dtype: int64
#
# Value counts for HOUR_APPR_PROCESS_START 대출신청시간대:
# 10    3014
# 11    2873
# 12    2719
# 13    2423
# 14    2162
# 9     2140
# 15    1894
# 16    1601
# 17    1165
# 8     1146
# 7      729
# 18     676
# 6      444
# 19     297
# 5      295
# 4      144
# 20     100
# 3       93
# 21      40
# 2       20
# 22      11
# 1        6
# 0        4
# 23       4
# Name: HOUR_APPR_PROCESS_START, dtype: int64
#
# Value counts for REG_CITY_NOT_LIVE_CITY 고객의등록지주소와실거주지일치여부:
# 0    22162
# 1     1838
# Name: REG_CITY_NOT_LIVE_CITY, dtype: int64
#
# Value counts for REG_CITY_NOT_WORK_CITY 고객의등록지주소와직장주소일치여부:
# 0    18431
# 1     5569
# Name: REG_CITY_NOT_WORK_CITY, dtype: int64
#
# Value counts for LIVE_CITY_NOT_WORK_CITY 고객의실거주지와직장주소일치여부:
# 0    19638
# 1     4362
# Name: LIVE_CITY_NOT_WORK_CITY, dtype: int64
#
# Value counts for ORGANIZATION_TYPE 근무회사유형:
# Business Entity Type 3    5311
# XNA                       4294
# Self-employed             3002
# Other                     1285
# Medicine                   855
# Government                 790
# Business Entity Type 2     788
# School                     685
# Trade: type 7              636
# Kindergarten               530
# Construction               491
# Business Entity Type 1     474
# Transport: type 4          429
# Industry: type 9           286
# Trade: type 3              260
# Industry: type 3           256
# Security                   248
# Bank                       236
# Housing                    232
# Agriculture                202
# Military                   201
# Industry: type 11          192
# Police                     182
# Postal                     176
# Transport: type 2          170
# Trade: type 2              166
# Security Ministries        139
# Services                   136
# Restaurant                 122
# Industry: type 7           111
# Transport: type 3           99
# University                  97
# Hotel                       91
# Industry: type 1            89
# Electricity                 88
# Industry: type 4            75
# Emergency                   61
# Trade: type 6               59
# Telecom                     54
# Industry: type 5            49
# Insurance                   48
# Advertising                 44
# Industry: type 2            34
# Trade: type 1               29
# Legal Services              27
# Industry: type 12           26
# Culture                     25
# Realtor                     25
# Mobile                      23
# Cleaning                    20
# Transport: type 1           19
# Industry: type 6             7
# Trade: type 4                7
# Industry: type 13            5
# Religion                     5
# Industry: type 10            4
# Trade: type 5                4
# Industry: type 8             1
# Name: ORGANIZATION_TYPE, dtype: int64
#
# Value counts for FLAG_DOCUMENT_2 문서2제공여부:
# 0    23996
# 1        4
# Name: FLAG_DOCUMENT_2, dtype: int64
#
# Value counts for FLAG_DOCUMENT_3 문서3제공여부:
# 1    17023
# 0     6977
# Name: FLAG_DOCUMENT_3, dtype: int64
#
# Value counts for FLAG_DOCUMENT_4 문서4제공여부:
# 0    23997
# 1        3
# Name: FLAG_DOCUMENT_4, dtype: int64
#
# Value counts for CB_SCORE_1 신용점수1:
# NaN          6146
# 57.464807       1
# 34.861203       1
# 78.456903       1
# 45.453237       1
#              ...
# 74.332357       1
# 48.726595       1
# 48.828257       1
# 35.608337       1
# 71.163710       1
# Name: CB_SCORE_1, Length: 17855, dtype: int64
#
# Value counts for CB_SCORE_2 신용점수2:
# NaN          8274
# 64.493920       1
# 76.714857       1
# 65.903267       1
# 38.518742       1
#              ...
# 59.014145       1
# 44.788331       1
# 83.702189       1
# 75.537881       1
# 50.173294       1
# Name: CB_SCORE_2, Length: 15727, dtype: int64
#
# Value counts for CB_SCORE_3 신용점수3:
# NaN           7108
# 100.000000       2
# 58.349224        1
# 71.921574        1
# 46.498394        1
#               ...
# 54.340466        1
# 51.239413        1
# 58.966202        1
# 64.836652        1
# 58.329626        1
# Name: CB_SCORE_3, Length: 16892, dtype: int64
#
# Value counts for TARGET 연체여부:
# 0    22007
# 1     1993
# Name: TARGET, dtype: int64

# %% [markdown]
# > 결측치 종류 : 'NaN', 'nan', 'XNA', 'Unknown' ▶ np.nan로 통일

# %%
adj_df = df.copy()

# %%
adj_df = adj_df.astype(str)
adj_df = adj_df.replace(['NaN', 'nan', 'XNA', 'Unknown'], np.nan)

# %%
adj_df = adj_df.astype(df.dtypes)

# %%
for column in adj_df.columns:
    value_counts = adj_df[column].value_counts(dropna = False)
    print(f"Value counts for {column} {column_info[column]}:\n{value_counts}\n")
# Out:
# Value counts for SK_ID_CURR 대출식별번호:
# 100002    1
# 337229    1
# 337317    1
# 337293    1
# 337288    1
#          ..
# 218660    1
# 218625    1
# 218609    1
# 218594    1
# 456228    1
# Name: SK_ID_CURR, Length: 24000, dtype: int64
#
# Value counts for NAME_CONTRACT_TYPE 계약유형:
# Cash loans         21733
# Revolving loans     2267
# Name: NAME_CONTRACT_TYPE, dtype: int64
#
# Value counts for CODE_GENDER 성별:
# F      11211
# NaN     7095
# M       5694
# Name: CODE_GENDER, dtype: int64
#
# Value counts for FLAG_OWN_REALTY 자가부동산보유여부:
# Y      9939
# NaN    9571
# N      4490
# Name: FLAG_OWN_REALTY, dtype: int64
#
# Value counts for CNT_CHILDREN 자녀수:
# 0    16859
# 1     4703
# 2     2046
# 3      341
# 4       41
# 5        9
# 7        1
# Name: CNT_CHILDREN, dtype: int64
#
# Value counts for AMT_INCOME_TOTAL 소득금액(USD):
# 135000.0    2779
# 112500.0    2422
# 157500.0    2052
# 180000.0    1860
# 90000.0     1785
#             ...
# 68400.0        1
# 118800.0       1
# 183375.0       1
# 113008.5       1
# 120784.5       1
# Name: AMT_INCOME_TOTAL, Length: 494, dtype: int64
#
# Value counts for AMT_CREDIT 신용대출금액(USD):
# NaN          7300
# 450000.0      567
# 675000.0      493
# 225000.0      410
# 180000.0      403
#              ...
# 1416825.0       1
# 494118.0        1
# 1665000.0       1
# 451647.0        1
# 995643.0        1
# Name: AMT_CREDIT, Length: 2267, dtype: int64
#
# Value counts for NAME_INCOME_TYPE 소득유형:
# Working                 12460
# Commercial associate     5527
# Pensioner                4294
# State servant            1714
# Student                     2
# Maternity leave             2
# Businessman                 1
# Name: NAME_INCOME_TYPE, dtype: int64
#
# Value counts for NAME_EDUCATION_TYPE 학력:
# Secondary / secondary special    17054
# Higher education                  5857
# Incomplete higher                  796
# Lower secondary                    278
# Academic degree                     15
# Name: NAME_EDUCATION_TYPE, dtype: int64
#
# Value counts for NAME_FAMILY_STATUS 결혼상태:
# Married                 15275
# Single / not married     3557
# Civil marriage           2336
# Separated                1527
# Widow                    1304
# NaN                         1
# Name: NAME_FAMILY_STATUS, dtype: int64
#
# Value counts for NAME_HOUSING_TYPE 주거형태:
# House / apartment      21213
# With parents            1206
# Municipal apartment      911
# Rented apartment         391
# Office apartment         203
# Co-op apartment           76
# Name: NAME_HOUSING_TYPE, dtype: int64
#
# Value counts for REGION_POPULATION_RELATIVE 거주지역의표준화된인구:
# NaN         7149
# 0.035792     893
# 0.046220     734
# 0.030755     656
# 0.026392     641
#             ...
# 0.001417      26
# 0.001333      11
# 0.000938       2
# 0.000533       1
# 0.000290       1
# Name: REGION_POPULATION_RELATIVE, Length: 82, dtype: int64
#
# Value counts for DAYS_BIRTH 대출신청시점에서의일단위나이(기준시점대비상대적인시간):
#  NaN        4749
# -17329.0       8
# -15961.0       7
# -21878.0       7
# -12846.0       7
#             ...
# -24266.0       1
# -18568.0       1
# -21506.0       1
# -11377.0       1
# -12847.0       1
# Name: DAYS_BIRTH, Length: 11222, dtype: int64
#
# Value counts for DAYS_EMPLOYED 대출신청시점에서의고객의근무일수(기준시점대비상대적인시간):
#  NaN         7149
#  365243.0    2999
# -222.0         14
# -212.0         13
# -147.0         13
#              ...
# -7274.0         1
# -4962.0         1
# -7087.0         1
# -4107.0         1
# -5168.0         1
# Name: DAYS_EMPLOYED, Length: 5431, dtype: int64
#
# Value counts for DAYS_REGISTRATION 대출신청이전에고객이등록정보를변경한시점사이의일수(기준시점대비상대적인시간):
#  NaN        9733
# -610.0         9
# -3402.0        8
# -2744.0        7
# -4514.0        7
#             ...
# -5250.0        1
# -6852.0        1
# -13504.0       1
# -9551.0        1
# -2970.0        1
# Name: DAYS_REGISTRATION, Length: 8207, dtype: int64
#
# Value counts for DAYS_ID_PUBLISH 대출신청이전에고객이신분증을변경한시점사이의일수(기준시점대비상대적인시간):
#  NaN       4741
# -4073.0      19
# -4053.0      18
# -4512.0      16
# -4008.0      16
#            ...
# -963.0        1
# -6126.0       1
# -3544.0       1
# -478.0        1
# -3747.0       1
# Name: DAYS_ID_PUBLISH, Length: 5247, dtype: int64
#
# Value counts for FLAG_MOBIL 휴대폰번호등록여부:
# 1    24000
# Name: FLAG_MOBIL, dtype: int64
#
# Value counts for FLAG_EMP_PHONE 고용주연락처등록여부:
# 1    19706
# 0     4294
# Name: FLAG_EMP_PHONE, dtype: int64
#
# Value counts for FLAG_WORK_PHONE 직장전화번호등록여부:
# 0    19112
# 1     4888
# Name: FLAG_WORK_PHONE, dtype: int64
#
# Value counts for FLAG_PHONE 집전화번호등록여부:
# 0    17276
# 1     6724
# Name: FLAG_PHONE, dtype: int64
#
# Value counts for FLAG_EMAIL 이메일주소등록여부:
# 0    22674
# 1     1326
# Name: FLAG_EMAIL, dtype: int64
#
# Value counts for REGION_RATING_CLIENT 거주지등급:
# 2    17656
# 3     3794
# 1     2550
# Name: REGION_RATING_CLIENT, dtype: int64
#
# Value counts for WEEKDAY_APPR_PROCESS_START 대출신청요일:
# TUESDAY      4135
# WEDNESDAY    4071
# FRIDAY       3995
# MONDAY       3977
# THURSDAY     3843
# SATURDAY     2592
# SUNDAY       1387
# Name: WEEKDAY_APPR_PROCESS_START, dtype: int64
#
# Value counts for HOUR_APPR_PROCESS_START 대출신청시간대:
# 10    3014
# 11    2873
# 12    2719
# 13    2423
# 14    2162
# 9     2140
# 15    1894
# 16    1601
# 17    1165
# 8     1146
# 7      729
# 18     676
# 6      444
# 19     297
# 5      295
# 4      144
# 20     100
# 3       93
# 21      40
# 2       20
# 22      11
# 1        6
# 0        4
# 23       4
# Name: HOUR_APPR_PROCESS_START, dtype: int64
#
# Value counts for REG_CITY_NOT_LIVE_CITY 고객의등록지주소와실거주지일치여부:
# 0    22162
# 1     1838
# Name: REG_CITY_NOT_LIVE_CITY, dtype: int64
#
# Value counts for REG_CITY_NOT_WORK_CITY 고객의등록지주소와직장주소일치여부:
# 0    18431
# 1     5569
# Name: REG_CITY_NOT_WORK_CITY, dtype: int64
#
# Value counts for LIVE_CITY_NOT_WORK_CITY 고객의실거주지와직장주소일치여부:
# 0    19638
# 1     4362
# Name: LIVE_CITY_NOT_WORK_CITY, dtype: int64
#
# Value counts for ORGANIZATION_TYPE 근무회사유형:
# Business Entity Type 3    5311
# NaN                       4294
# Self-employed             3002
# Other                     1285
# Medicine                   855
# Government                 790
# Business Entity Type 2     788
# School                     685
# Trade: type 7              636
# Kindergarten               530
# Construction               491
# Business Entity Type 1     474
# Transport: type 4          429
# Industry: type 9           286
# Trade: type 3              260
# Industry: type 3           256
# Security                   248
# Bank                       236
# Housing                    232
# Agriculture                202
# Military                   201
# Industry: type 11          192
# Police                     182
# Postal                     176
# Transport: type 2          170
# Trade: type 2              166
# Security Ministries        139
# Services                   136
# Restaurant                 122
# Industry: type 7           111
# Transport: type 3           99
# University                  97
# Hotel                       91
# Industry: type 1            89
# Electricity                 88
# Industry: type 4            75
# Emergency                   61
# Trade: type 6               59
# Telecom                     54
# Industry: type 5            49
# Insurance                   48
# Advertising                 44
# Industry: type 2            34
# Trade: type 1               29
# Legal Services              27
# Industry: type 12           26
# Culture                     25
# Realtor                     25
# Mobile                      23
# Cleaning                    20
# Transport: type 1           19
# Industry: type 6             7
# Trade: type 4                7
# Industry: type 13            5
# Religion                     5
# Industry: type 10            4
# Trade: type 5                4
# Industry: type 8             1
# Name: ORGANIZATION_TYPE, dtype: int64
#
# Value counts for FLAG_DOCUMENT_2 문서2제공여부:
# 0    23996
# 1        4
# Name: FLAG_DOCUMENT_2, dtype: int64
#
# Value counts for FLAG_DOCUMENT_3 문서3제공여부:
# 1    17023
# 0     6977
# Name: FLAG_DOCUMENT_3, dtype: int64
#
# Value counts for FLAG_DOCUMENT_4 문서4제공여부:
# 0    23997
# 1        3
# Name: FLAG_DOCUMENT_4, dtype: int64
#
# Value counts for CB_SCORE_1 신용점수1:
# NaN          6146
# 57.464807       1
# 34.861203       1
# 78.456903       1
# 45.453237       1
#              ...
# 74.332357       1
# 48.726595       1
# 48.828257       1
# 35.608337       1
# 71.163710       1
# Name: CB_SCORE_1, Length: 17855, dtype: int64
#
# Value counts for CB_SCORE_2 신용점수2:
# NaN          8274
# 64.493920       1
# 76.714857       1
# 65.903267       1
# 38.518742       1
#              ...
# 59.014145       1
# 44.788331       1
# 83.702189       1
# 75.537881       1
# 50.173294       1
# Name: CB_SCORE_2, Length: 15727, dtype: int64
#
# Value counts for CB_SCORE_3 신용점수3:
# NaN           7108
# 100.000000       2
# 58.349224        1
# 71.921574        1
# 46.498394        1
#               ...
# 54.340466        1
# 51.239413        1
# 58.966202        1
# 64.836652        1
# 58.329626        1
# Name: CB_SCORE_3, Length: 16892, dtype: int64
#
# Value counts for TARGET 연체여부:
# 0    22007
# 1     1993
# Name: TARGET, dtype: int64

# %% [markdown]
# *1.3 결과 → 결측치 표기 np.nan로 통일*

# %% [markdown]
# *1.4 Check Point → 범주형 변수들(object객체)의 유효값 체크*

# %%
# object 타입인 열들만 선택
object_columns = adj_df.select_dtypes(include=['object'])

# 각 열의 값의 빈도를 value_counts()로 계산
for column in object_columns:
    value_counts = object_columns[column].value_counts(dropna = False)
    print(f"Value counts for {column} {column_info[column]}:\n{value_counts}\n")
# Out:
# Value counts for NAME_CONTRACT_TYPE 계약유형:
# Cash loans         21733
# Revolving loans     2267
# Name: NAME_CONTRACT_TYPE, dtype: int64
#
# Value counts for CODE_GENDER 성별:
# F      11211
# NaN     7095
# M       5694
# Name: CODE_GENDER, dtype: int64
#
# Value counts for FLAG_OWN_REALTY 자가부동산보유여부:
# Y      9939
# NaN    9571
# N      4490
# Name: FLAG_OWN_REALTY, dtype: int64
#
# Value counts for NAME_INCOME_TYPE 소득유형:
# Working                 12460
# Commercial associate     5527
# Pensioner                4294
# State servant            1714
# Student                     2
# Maternity leave             2
# Businessman                 1
# Name: NAME_INCOME_TYPE, dtype: int64
#
# Value counts for NAME_EDUCATION_TYPE 학력:
# Secondary / secondary special    17054
# Higher education                  5857
# Incomplete higher                  796
# Lower secondary                    278
# Academic degree                     15
# Name: NAME_EDUCATION_TYPE, dtype: int64
#
# Value counts for NAME_FAMILY_STATUS 결혼상태:
# Married                 15275
# Single / not married     3557
# Civil marriage           2336
# Separated                1527
# Widow                    1304
# NaN                         1
# Name: NAME_FAMILY_STATUS, dtype: int64
#
# Value counts for NAME_HOUSING_TYPE 주거형태:
# House / apartment      21213
# With parents            1206
# Municipal apartment      911
# Rented apartment         391
# Office apartment         203
# Co-op apartment           76
# Name: NAME_HOUSING_TYPE, dtype: int64
#
# Value counts for WEEKDAY_APPR_PROCESS_START 대출신청요일:
# TUESDAY      4135
# WEDNESDAY    4071
# FRIDAY       3995
# MONDAY       3977
# THURSDAY     3843
# SATURDAY     2592
# SUNDAY       1387
# Name: WEEKDAY_APPR_PROCESS_START, dtype: int64
#
# Value counts for ORGANIZATION_TYPE 근무회사유형:
# Business Entity Type 3    5311
# NaN                       4294
# Self-employed             3002
# Other                     1285
# Medicine                   855
# Government                 790
# Business Entity Type 2     788
# School                     685
# Trade: type 7              636
# Kindergarten               530
# Construction               491
# Business Entity Type 1     474
# Transport: type 4          429
# Industry: type 9           286
# Trade: type 3              260
# Industry: type 3           256
# Security                   248
# Bank                       236
# Housing                    232
# Agriculture                202
# Military                   201
# Industry: type 11          192
# Police                     182
# Postal                     176
# Transport: type 2          170
# Trade: type 2              166
# Security Ministries        139
# Services                   136
# Restaurant                 122
# Industry: type 7           111
# Transport: type 3           99
# University                  97
# Hotel                       91
# Industry: type 1            89
# Electricity                 88
# Industry: type 4            75
# Emergency                   61
# Trade: type 6               59
# Telecom                     54
# Industry: type 5            49
# Insurance                   48
# Advertising                 44
# Industry: type 2            34
# Trade: type 1               29
# Legal Services              27
# Industry: type 12           26
# Culture                     25
# Realtor                     25
# Mobile                      23
# Cleaning                    20
# Transport: type 1           19
# Industry: type 6             7
# Trade: type 4                7
# Industry: type 13            5
# Religion                     5
# Industry: type 10            4
# Trade: type 5                4
# Industry: type 8             1
# Name: ORGANIZATION_TYPE, dtype: int64

# %% [markdown]
# *1.4 결과 → (1) 각 범주형 변수들별로 크게 묶을 수 있는 것들은 대분류 변수들 생성
# (2) 성별 / 자가부동산보유여부에 결측값이 생각보다 많음 ▶ 어떻게 처리할지 고민 필요*

# %% [markdown]
# < 유효값 정보 참고 >
#
# 1. NAME_INCOME_TYPE 소득유형
# Working - 근로자 : 12460
# Commercial associate - 상업 공동주택 : 5527
# Pensioner - 연금 수령자 : 4294
# State servant - 공무원 : 1714
# Student - 학생 : 2
# Maternity leave - 육아 휴가 : 2
# Businessman - 사업가 : 1
#
#
# 2. NAME_EDUCATION_TYPE 학력
# Secondary / secondary special - 중등 교육 / 중등 특별 교육: 17054
# Higher education - 고등 교육: 5857
# Incomplete higher - 미완료된 고등 교육: 796
# Lower secondary - 초등 교육: 278
# Academic degree - 학위: 15
#
#
# 3. NAME_FAMILY_STATUS 결혼상태
# Married - 기혼: 15275
# Single / not married - 미혼: 3557
# Civil marriage - 민사결혼: 2336
# Separated - 별거: 1527
# Widow - 사별: 1304
# Unknown - 알 수 없음: 1
#
#
# 4. NAME_HOUSING_TYPE 주거형태
# House / apartment - 주택 / 아파트: 21213
# With parents - 부모님과 함께: 1206
# Municipal apartment - 시립 아파트: 911
# Rented apartment - 임대 아파트: 391
# Office apartment - 사무 아파트: 203
# Co-op apartment - 주택조합 아파트: 76
#
#
# 5. ORGANIZATION_TYPE 근무회사유형
# Business Entity Type 3 - 사업 엔터티 유형 3: 5311
# XNA - XNA: 4294
# Self-employed - 자영업: 3002
# Other - 기타: 1285
# Medicine - 의학: 855
# Government - 정부: 790
# Business Entity Type 2 - 사업 엔터티 유형 2: 788
# School - 학교: 685
# Trade: type 7 - 거래: 유형 7: 636
# Kindergarten - 유치원: 530
# Construction - 건설: 491
# Business Entity Type 1 - 사업 엔터티 유형 1: 474
# Transport: type 4 - 운송: 유형 4: 429
# Industry: type 9 - 산업: 유형 9: 286
# Trade: type 3 - 거래: 유형 3: 260
# Industry: type 3 - 산업: 유형 3: 256
# Security - 보안: 248
# Bank - 은행: 236
# Housing - 주택: 232
# Agriculture - 농업: 202
# Military - 군대: 201
# Industry: type 11 - 산업: 유형 11: 192
# Police - 경찰: 182
# Postal - 우체국: 176
# Transport: type 2 - 운송: 유형 2: 170
# Trade: type 2 - 거래: 유형 2: 166
# Security Ministries - 보안부: 139
# Services - 서비스: 136
# Restaurant - 레스토랑: 122
# Industry: type 7 - 산업: 유형 7: 111
# Transport: type 3 - 운송: 유형 3: 99
# University - 대학교: 97
# Hotel - 호텔: 91
# Industry: type 1 - 산업: 유형 1: 89
# Electricity - 전기: 88
# Industry: type 4 - 산업: 유형 4: 75
# Emergency - 비상: 61
# Trade: type 6 - 거래: 유형 6: 59
# Telecom - 통신: 54
# Industry: type 5 - 산업: 유형 5: 49
# Insurance - 보험: 48
# Advertising - 광고: 44
# Industry: type 2 - 산업: 유형 2: 34
# Trade: type 1 - 거래: 유형 1: 29
# Legal Services - 법률 서비스: 27
# Industry: type 12 - 산업: 유형 12: 26
# Culture - 문화: 25
# Realtor - 부동산 중개인: 25
# Mobile - 모바일: 23
# Cleaning - 청소: 20
# Transport: type 1 - 운송: 유형 1: 19
# Industry: type 6 - 산업: 유형 6: 7
# Trade: type 4 - 거래: 유형 4: 7
# Industry: type 13 - 산업: 유형 13: 5
# Religion - 종교: 5
# Industry: type 10 - 산업: 유형 10: 4
# Trade: type 5 - 거래: 유형 5: 4
# Industry: type 8 - 산업: 유형 8: 1

# %% [markdown]
# *1.4.대분류 변수 생성*
# **ORGANIZATION_TYPE 근무회사유형**

# %%
adj_df['ADJ_ORGANIZATION_TYPE'] = adj_df['ORGANIZATION_TYPE'].copy()

# %%
adj_df['ADJ_ORGANIZATION_TYPE'] = adj_df['ADJ_ORGANIZATION_TYPE'].str.replace(r'^Trade.*', 'Trade', regex = True)
adj_df['ADJ_ORGANIZATION_TYPE'] = adj_df['ADJ_ORGANIZATION_TYPE'].str.replace('^Industry.*', 'Industry', regex = True)
adj_df['ADJ_ORGANIZATION_TYPE'] = adj_df['ADJ_ORGANIZATION_TYPE'].str.replace('^Transport.*', 'Transport', regex = True)
adj_df['ADJ_ORGANIZATION_TYPE'] = adj_df['ADJ_ORGANIZATION_TYPE'].str.replace('^Business Entity.*', 'Business Entity', regex = True)

# %%
adj_df['ADJ_ORGANIZATION_TYPE'].value_counts(dropna=False)
# Out:
# Business Entity        6573
# NaN                    4294
# Self-employed          3002
# Other                  1285
# Trade                  1161
# Industry               1135
# Medicine                855
# Government              790
# Transport               717
# School                  685
# Kindergarten            530
# Construction            491
# Security                248
# Bank                    236
# Housing                 232
# Agriculture             202
# Military                201
# Police                  182
# Postal                  176
# Security Ministries     139
# Services                136
# Restaurant              122
# University               97
# Hotel                    91
# Electricity              88
# Emergency                61
# Telecom                  54
# Insurance                48
# Advertising              44
# Legal Services           27
# Culture                  25
# Realtor                  25
# Mobile                   23
# Cleaning                 20
# Religion                  5
# Name: ADJ_ORGANIZATION_TYPE, dtype: int64

# %%
# 직업군을 그룹핑한 딕셔너리 생성
organization_type_dict = {
    'Business and Self-employed': ['Business Entity', 'Self-employed', 'Trade'],
    'Industry and Construction': ['Industry', 'Construction'],
    'Medicine and Healthcare': ['Medicine'],
    'Government and Security': ['Government', 'Security', 'Security Ministries', 'Military', 'Police'],
    'Education': ['School', 'Kindergarten', 'University'],
    'Housing and Real Estate': ['Housing', 'Bank', 'Real Estate'],
    'Logistics and Services': ['Transport', 'Postal', 'Services'],
    'Hospitality': ['Restaurant', 'Hotel'],
    'Utilities and Telecom': ['Electricity', 'Telecom'],
    'Others': ['Other', 'Agriculture', 'Emergency', 'Insurance', 'Advertising', 'Legal Services', 'Culture', 'Realtor', 'Mobile', 'Cleaning', 'Religion']
}

# %%
# {
#     '사업 및 자영업': ['사업 엔터티', '자영업', '거래'],
#     '산업 및 건설': ['산업', '건설'],
#     '의학 및 의료': ['의학'],
#     '정부 및 보안': ['정부', '보안', '보안 기관', '군대', '경찰'],
#     '교육': ['학교', '유치원', '대학교'],
#     '주택 및 부동산': ['주택', '은행', '부동산'],
#     '물류 및 서비스': ['운송', '우편', '서비스'],
#     '식음료업': ['레스토랑', '호텔'],
#     '공공 및 통신사업': ['전기', '통신'],
#     '기타': ['기타', '농업', '비상', '보험', '광고', '법률 서비스', '문화', '부동산 중개인', '휴대폰', '청소', '종교']
# }

# %%
for category, occupations in organization_type_dict.items():
    adj_df.loc[adj_df['ADJ_ORGANIZATION_TYPE'].isin(occupations), 'ADJ_ORGANIZATION_TYPE'] = category

# %%
adj_df['ADJ_ORGANIZATION_TYPE'].value_counts(dropna=False)
# Out:
# Business and Self-employed    10736
# NaN                            4294
# Others                         1765
# Industry and Construction      1626
# Government and Security        1560
# Education                      1312
# Logistics and Services         1029
# Medicine and Healthcare         855
# Housing and Real Estate         468
# Hospitality                     213
# Utilities and Telecom           142
# Name: ADJ_ORGANIZATION_TYPE, dtype: int64

# %% [markdown]
# *1.5 Check Point : 결측치 있는 변수들 살펴보기*

# %%
print("원래 데이터프레임 사이즈 : " + str(adj_df.shape) + '\n결측치 제거 후 사이즈 : ' + str(adj_df.dropna().shape))
# Out:
# 원래 데이터프레임 사이즈 : (24000, 36)
# 결측치 제거 후 사이즈 : (364, 36)

# %%
# 결측치가 있는 변수 추출
# columns_with_missing_values = df.columns[df.isnull().any()]
# for col in columns_with_missing_values : 
for col in df.columns : 
    na_cnt = df[col].isna().sum()
    print(col + ', ' + column_info[col] + ':' + str(na_cnt))
# Out:
# SK_ID_CURR, 대출식별번호:0
# NAME_CONTRACT_TYPE, 계약유형:0
# CODE_GENDER, 성별:7094
# FLAG_OWN_REALTY, 자가부동산보유여부:9571
# CNT_CHILDREN, 자녀수:0
# AMT_INCOME_TOTAL, 소득금액(USD):0
# AMT_CREDIT, 신용대출금액(USD):7300
# NAME_INCOME_TYPE, 소득유형:0
# NAME_EDUCATION_TYPE, 학력:0
# NAME_FAMILY_STATUS, 결혼상태:0
# NAME_HOUSING_TYPE, 주거형태:0
# REGION_POPULATION_RELATIVE, 거주지역의표준화된인구:7149
# DAYS_BIRTH, 대출신청시점에서의일단위나이(기준시점대비상대적인시간):4749
# DAYS_EMPLOYED, 대출신청시점에서의고객의근무일수(기준시점대비상대적인시간):7149
# DAYS_REGISTRATION, 대출신청이전에고객이등록정보를변경한시점사이의일수(기준시점대비상대적인시간):9733
# DAYS_ID_PUBLISH, 대출신청이전에고객이신분증을변경한시점사이의일수(기준시점대비상대적인시간):4741
# FLAG_MOBIL, 휴대폰번호등록여부:0
# FLAG_EMP_PHONE, 고용주연락처등록여부:0
# FLAG_WORK_PHONE, 직장전화번호등록여부:0
# FLAG_PHONE, 집전화번호등록여부:0
# FLAG_EMAIL, 이메일주소등록여부:0
# REGION_RATING_CLIENT, 거주지등급:0
# WEEKDAY_APPR_PROCESS_START, 대출신청요일:0
# HOUR_APPR_PROCESS_START, 대출신청시간대:0
# REG_CITY_NOT_LIVE_CITY, 고객의등록지주소와실거주지일치여부:0
# REG_CITY_NOT_WORK_CITY, 고객의등록지주소와직장주소일치여부:0
# LIVE_CITY_NOT_WORK_CITY, 고객의실거주지와직장주소일치여부:0
# ORGANIZATION_TYPE, 근무회사유형:0
# FLAG_DOCUMENT_2, 문서2제공여부:0
# FLAG_DOCUMENT_3, 문서3제공여부:0
# FLAG_DOCUMENT_4, 문서4제공여부:0
# CB_SCORE_1, 신용점수1:6146
# CB_SCORE_2, 신용점수2:8274
# CB_SCORE_3, 신용점수3:7108
# TARGET, 연체여부:0

# %% [markdown]
# *1.5 결과 → 범주형 변수들(object객체)의 유효값 체크*

# %% [markdown]
# *1.6 Check Point : 거주지역의 표준화된 인구 ▶ 시 기준으로 나눈건진 모르겠으나 같은 값이면 같은 지역 의미할 듯*

# %%
adj_df['REGION_POPULATION_RELATIVE'].value_counts()
# Out:
# 0.035792    893
# 0.046220    734
# 0.030755    656
# 0.026392    641
# 0.025164    632
#            ...
# 0.001417     26
# 0.001333     11
# 0.000938      2
# 0.000533      1
# 0.000290      1
# Name: REGION_POPULATION_RELATIVE, Length: 81, dtype: int64

# %%
unique_vals = adj_df['REGION_POPULATION_RELATIVE'].dropna().unique()

# %%
label0 = 1

# %%
for val in unique_vals : 
    adj_df.loc[df['REGION_POPULATION_RELATIVE'] == val, 'ADJ_REGION_POPULATION_RELATIVE'] = label0 
    label0 += 1

# %%
adj_df['ADJ_REGION_POPULATION_RELATIVE'].value_counts(dropna=False)
# Out:
# NaN     7149
# 13.0     893
# 18.0     734
# 40.0     656
# 3.0      641
#         ...
# 71.0      26
# 78.0      11
# 80.0       2
# 79.0       1
# 81.0       1
# Name: ADJ_REGION_POPULATION_RELATIVE, Length: 82, dtype: int64

# %% [markdown]
# *1.7 Check Point : 자녀 수 - 다자녀는 하나로 그룹핑*

# %%
adj_df['CNT_CHILDREN'].value_counts() # 3명 이상은 묶어보자
# Out:
# 0    16859
# 1     4703
# 2     2046
# 3      341
# 4       41
# 5        9
# 7        1
# Name: CNT_CHILDREN, dtype: int64

# %%
adj_df['ADJ_CNT_CHILDREN'] = adj_df['CNT_CHILDREN']

# %%
adj_df.loc[adj_df['CNT_CHILDREN']>=3, 'ADJ_CNT_CHILDREN'] = 3

# %% [markdown]
# *1.7 결과 다자녀 3으로 묶기*

# %% [markdown]
# *1.8 Check Point : 휴대폰 등록 여부는 유효값 1개 -> 변별력없으므로 drop*

# %%
adj_df.drop(columns = 'FLAG_MOBIL', inplace = True)

# %% [markdown]
# *1.9 Check Point : Days 변수들 단위 변환*

# %%
days_lst = ['DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH']

# %%
for day in days_lst : 
    print(day + ':' + column_info[day])
# Out:
# DAYS_BIRTH:대출신청시점에서의일단위나이(기준시점대비상대적인시간)
# DAYS_EMPLOYED:대출신청시점에서의고객의근무일수(기준시점대비상대적인시간)
# DAYS_REGISTRATION:대출신청이전에고객이등록정보를변경한시점사이의일수(기준시점대비상대적인시간)
# DAYS_ID_PUBLISH:대출신청이전에고객이신분증을변경한시점사이의일수(기준시점대비상대적인시간)

# %% [markdown]
# > 나이 변환

# %%
df['DAYS_BIRTH'].value_counts()
# Out:
# -17329.0    8
# -11290.0    7
# -12846.0    7
# -13427.0    7
# -21878.0    7
#            ..
# -24266.0    1
# -18568.0    1
# -21506.0    1
# -11377.0    1
# -12847.0    1
# Name: DAYS_BIRTH, Length: 11221, dtype: int64

# %%
adj_df['ADJ_DAYS_BIRTH'] = round(abs(df['DAYS_BIRTH']/365) - 1)

# %%
adj_df['ADJ_DAYS_BIRTH'].value_counts(ascending = True)
# Out:
# 68.0     24
# 20.0     28
# 67.0     98
# 21.0    126
# 66.0    127
# 65.0    147
# 23.0    231
# 22.0    239
# 64.0    262
# 24.0    262
# 25.0    268
# 63.0    305
# 61.0    353
# 62.0    364
# 59.0    381
# 57.0    383
# 58.0    398
# 60.0    398
# 49.0    405
# 56.0    406
# 55.0    415
# 51.0    421
# 26.0    422
# 47.0    422
# 50.0    427
# 45.0    431
# 54.0    433
# 48.0    438
# 46.0    451
# 44.0    458
# 53.0    466
# 52.0    470
# 33.0    470
# 28.0    473
# 31.0    480
# 35.0    483
# 34.0    488
# 30.0    493
# 32.0    495
# 43.0    517
# 39.0    519
# 29.0    533
# 40.0    533
# 37.0    534
# 41.0    542
# 36.0    550
# 27.0    552
# 38.0    561
# 42.0    569
# Name: ADJ_DAYS_BIRTH, dtype: int64

# %% [markdown]
# > 근무일수 변환

# %%
adj_df['DAYS_EMPLOYED'].value_counts(dropna = False)
# Out:
#  NaN         7149
#  365243.0    2999
# -222.0         14
# -212.0         13
# -147.0         13
#              ...
# -7274.0         1
# -4962.0         1
# -7087.0         1
# -4107.0         1
# -5168.0         1
# Name: DAYS_EMPLOYED, Length: 5431, dtype: int64

# %%
adj_df['ADJ_DAYS_EMPLOYED'] = -(round(df['DAYS_EMPLOYED']/365)-1)

# %%
adj_df['ADJ_DAYS_EMPLOYED'].value_counts()
# Out:
# -1000.0    2999
#  2.0       1928
#  3.0       1693
#  4.0       1554
#  5.0       1201
#  6.0       1074
#  7.0        829
#  8.0        777
#  9.0        676
#  10.0       534
#  1.0        517
#  11.0       479
#  12.0       365
#  13.0       288
#  14.0       256
#  15.0       252
#  16.0       212
#  17.0       143
#  18.0       122
#  19.0       118
#  20.0       106
#  21.0        95
#  22.0        95
#  23.0        80
#  24.0        59
#  26.0        40
#  27.0        39
#  29.0        39
#  25.0        35
#  33.0        30
#  31.0        29
#  32.0        27
#  35.0        26
#  30.0        26
#  28.0        25
#  34.0        21
#  36.0        16
#  38.0        11
#  40.0         8
#  37.0         8
#  41.0         4
#  39.0         4
#  44.0         2
#  43.0         2
#  42.0         2
#  46.0         2
#  47.0         2
#  45.0         1
# Name: ADJ_DAYS_EMPLOYED, dtype: int64

# %% [markdown]
# ADJ_DAYS_EMPLOYED = -1001 인 데이터를 결측으로 처리해야할지 고민

# %% [markdown]
# > 등록정보변경시점일수 변환

# %%
adj_df['DAYS_REGISTRATION'].value_counts(dropna = False)
# Out:
#  NaN        9733
# -610.0         9
# -3402.0        8
# -2744.0        7
# -4514.0        7
#             ...
# -5250.0        1
# -6852.0        1
# -13504.0       1
# -9551.0        1
# -2970.0        1
# Name: DAYS_REGISTRATION, Length: 8207, dtype: int64

# %%
adj_df['ADJ_DAYS_REGISTRATION'] = round(abs(df['DAYS_REGISTRATION']/365)) + 1

# %%
adj_df['ADJ_DAYS_REGISTRATION'].value_counts(dropna = False)
# Out:
# NaN     9733
# 2.0      718
# 3.0      699
# 4.0      655
# 14.0     636
# 13.0     621
# 12.0     556
# 15.0     536
# 9.0      532
# 5.0      530
# 8.0      525
# 11.0     510
# 10.0     503
# 6.0      491
# 7.0      445
# 1.0      424
# 17.0     405
# 16.0     397
# 18.0     389
# 23.0     386
# 19.0     376
# 21.0     349
# 22.0     345
# 20.0     343
# 25.0     327
# 24.0     321
# 27.0     302
# 26.0     290
# 28.0     285
# 29.0     223
# 30.0     198
# 31.0     141
# 32.0     128
# 33.0     108
# 34.0      96
# 35.0      82
# 36.0      80
# 37.0      78
# 38.0      54
# 40.0      42
# 39.0      35
# 42.0      20
# 43.0      20
# 41.0      19
# 46.0      11
# 44.0       8
# 45.0       7
# 49.0       4
# 48.0       4
# 47.0       4
# 52.0       3
# 57.0       2
# 58.0       1
# 51.0       1
# 69.0       1
# 54.0       1
# Name: ADJ_DAYS_REGISTRATION, dtype: int64

# %% [markdown]
# > 신분증변경시점일수 변환

# %%
adj_df['DAYS_ID_PUBLISH'].value_counts(dropna = False)
# Out:
#  NaN       4741
# -4073.0      19
# -4053.0      18
# -4512.0      16
# -4008.0      16
#            ...
# -963.0        1
# -6126.0       1
# -3544.0       1
# -478.0        1
# -3747.0       1
# Name: DAYS_ID_PUBLISH, Length: 5247, dtype: int64

# %%
adj_df['ADJ_DAYS_ID_PUBLISH'] = round(abs(df['DAYS_ID_PUBLISH']/365))+1

# %%
adj_df['ADJ_DAYS_ID_PUBLISH'].value_counts(dropna = False)
# Out:
# NaN     4741
# 13.0    2640
# 12.0    2243
# 14.0    1989
# 8.0     1243
# 10.0    1174
# 9.0     1124
# 6.0     1100
# 7.0     1099
# 4.0     1086
# 3.0     1048
# 11.0    1045
# 5.0     1017
# 2.0      959
# 15.0     710
# 1.0      497
# 16.0     190
# 17.0      79
# 18.0      16
# Name: ADJ_DAYS_ID_PUBLISH, dtype: int64

# %% [markdown]
# *2. Check Point : 변수간 관계*

# %%
# correlation_matrix = adj_df.corr()
# percent_corr_matrix = correlation_matrix * 100
# # 히트맵 그리기
# plt.figure(figsize=(20, 8))  # 그래프 크기 조정
# sns.heatmap(percent_corr_matrix, annot=True,fmt=".1f", cmap='coolwarm', center=0)
# plt.title("Correlation Heatmap")  # 그래프 제목
# plt.show()

# %%
pd.crosstab(adj_df['ADJ_DAYS_EMPLOYED'], adj_df['FLAG_EMP_PHONE'])
# Out:
# FLAG_EMP_PHONE        0     1
# ADJ_DAYS_EMPLOYED
# -1000.0            2999     0
#  1.0                  0   517
#  2.0                  0  1928
#  3.0                  0  1693
#  4.0                  0  1554
#  5.0                  0  1201
#  6.0                  0  1074
#  7.0                  0   829
#  8.0                  0   777
#  9.0                  0   676
#  10.0                 0   534
#  11.0                 0   479
#  12.0                 0   365
#  13.0                 0   288
#  14.0                 0   256
#  15.0                 0   252
#  16.0                 0   212
#  17.0                 0   143
#  18.0                 0   122
#  19.0                 0   118
#  20.0                 0   106
#  21.0                 0    95
#  22.0                 0    95
#  23.0                 0    80
#  24.0                 0    59
#  25.0                 0    35
#  26.0                 0    40
#  27.0                 0    39
#  28.0                 0    25
#  29.0                 0    39
#  30.0                 0    26
#  31.0                 0    29
#  32.0                 0    27
#  33.0                 0    30
#  34.0                 0    21
#  35.0                 0    26
#  36.0                 0    16
#  37.0                 0     8
#  38.0                 0    11
#  39.0                 0     4
#  40.0                 0     8
#  41.0                 0     4
#  42.0                 0     2
#  43.0                 0     2
#  44.0                 0     2
#  45.0                 0     1
#  46.0                 0     2
#  47.0                 0     2

# %% [markdown]
# > 직업쪽이랑 연관이 있겠지

# %%
adj_df.columns
# Out:
# Index(['SK_ID_CURR', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_REALTY',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'FLAG_EMP_PHONE',
#        'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL', 'REGION_RATING_CLIENT',
#        'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START',
#        'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY',
#        'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE', 'FLAG_DOCUMENT_2',
#        'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'CB_SCORE_1', 'CB_SCORE_2',
#        'CB_SCORE_3', 'TARGET', 'ADJ_ORGANIZATION_TYPE',
#        'ADJ_REGION_POPULATION_RELATIVE', 'ADJ_CNT_CHILDREN', 'ADJ_DAYS_BIRTH',
#        'ADJ_DAYS_EMPLOYED', 'ADJ_DAYS_REGISTRATION', 'ADJ_DAYS_ID_PUBLISH'],
#       dtype='object')

# %%
# 교차표 생성
cross_tab = pd.crosstab([adj_df['ADJ_ORGANIZATION_TYPE'], adj_df['ADJ_DAYS_EMPLOYED']], adj_df['FLAG_EMP_PHONE'])

# %%
test_df = adj_df.loc[adj_df['FLAG_EMP_PHONE']==0, :]

# %%
for col in adj_df.columns : 
    print(test_df[col].value_counts(dropna = False))
# Out:
# 100125    1
# 332445    1
# 331511    1
# 331575    1
# 331586    1
#          ..
# 217649    1
# 218023    1
# 218033    1
# 218045    1
# 456095    1
# Name: SK_ID_CURR, Length: 4294, dtype: int64
# Cash loans         4050
# Revolving loans     244
# Name: NAME_CONTRACT_TYPE, dtype: int64
# F      2465
# NaN    1276
# M       553
# Name: CODE_GENDER, dtype: int64
# Y      1929
# NaN    1739
# N       626
# Name: FLAG_OWN_REALTY, dtype: int64
# 0    4131
# 1     125
# 2      25
# 3      10
# 4       2
# 5       1
# Name: CNT_CHILDREN, dtype: int64
# 135000.0    447
# 112500.0    438
# 90000.0     402
# 157500.0    318
# 67500.0     283
#            ...
# 177750.0      1
# 499500.0      1
# 150750.0      1
# 66600.0       1
# 333000.0      1
# Name: AMT_INCOME_TOTAL, Length: 210, dtype: int64
# NaN          1312
# 675000.0      111
# 254700.0       96
# 225000.0       91
# 450000.0       64
#              ...
# 513040.5        1
# 358344.0        1
# 616261.5        1
# 1212426.0       1
# 733176.0        1
# Name: AMT_CREDIT, Length: 931, dtype: int64
# Pensioner    4294
# Name: NAME_INCOME_TYPE, dtype: int64
# Secondary / secondary special    3486
# Higher education                  637
# Lower secondary                   121
# Incomplete higher                  46
# Academic degree                     4
# Name: NAME_EDUCATION_TYPE, dtype: int64
# Married                 2476
# Widow                    786
# Single / not married     467
# Separated                292
# Civil marriage           273
# Name: NAME_FAMILY_STATUS, dtype: int64
# House / apartment      4082
# Municipal apartment     149
# Office apartment         22
# With parents             21
# Rented apartment         14
# Co-op apartment           6
# Name: NAME_HOUSING_TYPE, dtype: int64
# NaN         1275
# 0.030755     138
# 0.028663     123
# 0.035792     121
# 0.026392     119
#             ...
# 0.002506       5
# 0.003541       3
# 0.001333       2
# 0.000533       1
# 0.000938       1
# Name: REGION_POPULATION_RELATIVE, Length: 81, dtype: int64
#  NaN        840
# -22972.0      5
# -22940.0      5
# -21713.0      4
# -20532.0      4
#            ...
# -20169.0      1
# -24641.0      1
# -24547.0      1
# -22074.0      1
# -19105.0      1
# Name: DAYS_BIRTH, Length: 2615, dtype: int64
# 365243.0    2999
# NaN         1295
# Name: DAYS_EMPLOYED, dtype: int64
#  NaN        1713
# -91.0          3
# -2757.0        3
# -8328.0        3
# -1186.0        3
#             ...
# -8279.0        1
# -7741.0        1
# -12104.0       1
# -743.0         1
# -4133.0        1
# Name: DAYS_REGISTRATION, Length: 2361, dtype: int64
#  NaN       902
# -3996.0      8
# -4375.0      8
# -4316.0      7
# -4528.0      7
#           ...
# -2364.0      1
# -2320.0      1
# -3370.0      1
# -3400.0      1
# -2662.0      1
# Name: DAYS_ID_PUBLISH, Length: 1936, dtype: int64
# 0    4294
# Name: FLAG_EMP_PHONE, dtype: int64
# 0    4294
# Name: FLAG_WORK_PHONE, dtype: int64
# 0    3046
# 1    1248
# Name: FLAG_PHONE, dtype: int64
# 0    4188
# 1     106
# Name: FLAG_EMAIL, dtype: int64
# 2    3211
# 3     723
# 1     360
# Name: REGION_RATING_CLIENT, dtype: int64
# FRIDAY       796
# WEDNESDAY    764
# TUESDAY      720
# THURSDAY     706
# MONDAY       700
# SATURDAY     402
# SUNDAY       206
# Name: WEEKDAY_APPR_PROCESS_START, dtype: int64
# 10    619
# 11    580
# 9     496
# 12    486
# 13    412
# 14    375
# 8     277
# 15    275
# 16    209
# 7     153
# 17    115
# 6      85
# 5      66
# 18     60
# 4      27
# 19     24
# 3      19
# 20      7
# 2       3
# 21      3
# 23      2
# 1       1
# Name: HOUR_APPR_PROCESS_START, dtype: int64
# 0    4193
# 1     101
# Name: REG_CITY_NOT_LIVE_CITY, dtype: int64
# 0    4294
# Name: REG_CITY_NOT_WORK_CITY, dtype: int64
# 0    4294
# Name: LIVE_CITY_NOT_WORK_CITY, dtype: int64
# NaN    4294
# Name: ORGANIZATION_TYPE, dtype: int64
# 0    4294
# Name: FLAG_DOCUMENT_2, dtype: int64
# 0    2242
# 1    2052
# Name: FLAG_DOCUMENT_3, dtype: int64
# 0    4294
# Name: FLAG_DOCUMENT_4, dtype: int64
# NaN          1165
# 37.482198       1
# 74.943064       1
# 63.414825       1
# 44.649045       1
#              ...
# 37.383079       1
# 31.493163       1
# 64.772803       1
# 60.383451       1
# 55.568876       1
# Name: CB_SCORE_1, Length: 3130, dtype: int64
# NaN          1508
# 69.266436       1
# 64.756461       1
# 57.795077       1
# 47.822532       1
#              ...
# 60.764688       1
# 74.517574       1
# 66.829482       1
# 67.398774       1
# 64.318198       1
# Name: CB_SCORE_2, Length: 2787, dtype: int64
# NaN          1304
# 69.085712       1
# 73.590093       1
# 76.887819       1
# 63.591479       1
#              ...
# 70.885373       1
# 61.632801       1
# 66.129259       1
# 72.317803       1
# 56.609319       1
# Name: CB_SCORE_3, Length: 2991, dtype: int64
# 0    4041
# 1     253
# Name: TARGET, dtype: int64
# NaN    4294
# Name: ADJ_ORGANIZATION_TYPE, dtype: int64
# NaN     1275
# 40.0     138
# 10.0     123
# 13.0     121
# 3.0      119
#         ...
# 67.0       5
# 75.0       3
# 78.0       2
# 79.0       1
# 80.0       1
# Name: ADJ_REGION_POPULATION_RELATIVE, Length: 81, dtype: int64
# 0    4131
# 1     125
# 2      25
# 3      13
# Name: ADJ_CNT_CHILDREN, dtype: int64
# NaN     840
# 60.0    310
# 62.0    307
# 61.0    278
# 58.0    266
# 63.0    265
# 59.0    251
# 64.0    228
# 57.0    227
# 55.0    226
# 56.0    225
# 65.0    138
# 54.0    134
# 66.0    116
# 67.0     88
# 53.0     84
# 52.0     52
# 51.0     39
# 50.0     33
# 49.0     24
# 68.0     21
# 46.0     17
# 45.0     14
# 47.0     14
# 48.0     13
# 42.0     13
# 39.0      7
# 36.0      7
# 35.0      7
# 43.0      7
# 41.0      7
# 38.0      6
# 37.0      6
# 44.0      5
# 40.0      4
# 26.0      2
# 27.0      2
# 33.0      2
# 25.0      2
# 29.0      2
# 30.0      2
# 22.0      1
# 21.0      1
# 34.0      1
# Name: ADJ_DAYS_BIRTH, dtype: int64
# -1000.0    2999
#  NaN       1295
# Name: ADJ_DAYS_EMPLOYED, dtype: int64
# NaN     1713
# 4.0      102
# 14.0      93
# 2.0       88
# 5.0       85
# 27.0      83
# 12.0      83
# 3.0       83
# 13.0      79
# 10.0      76
# 30.0      74
# 28.0      73
# 9.0       71
# 8.0       70
# 19.0      70
# 15.0      70
# 22.0      68
# 11.0      68
# 29.0      68
# 25.0      63
# 17.0      63
# 23.0      63
# 1.0       62
# 6.0       60
# 16.0      59
# 20.0      59
# 7.0       57
# 26.0      57
# 21.0      54
# 32.0      52
# 24.0      52
# 31.0      51
# 18.0      51
# 34.0      51
# 36.0      47
# 33.0      46
# 37.0      44
# 35.0      40
# 40.0      31
# 38.0      27
# 39.0      22
# 43.0      16
# 41.0      14
# 42.0      12
# 44.0       6
# 47.0       4
# 46.0       4
# 45.0       4
# 48.0       2
# 52.0       1
# 57.0       1
# 49.0       1
# 69.0       1
# Name: ADJ_DAYS_REGISTRATION, dtype: int64
# NaN     902
# 13.0    862
# 12.0    708
# 14.0    613
# 15.0    221
# 11.0    198
# 10.0    148
# 8.0     111
# 9.0     108
# 7.0      80
# 6.0      71
# 3.0      59
# 5.0      55
# 2.0      49
# 4.0      43
# 16.0     34
# 1.0      17
# 17.0     14
# 18.0      1
# Name: ADJ_DAYS_ID_PUBLISH, dtype: int64

# %% [markdown]
# <!-- Pensioner    4294 # 연금수령자 -> 나이가 많겠군
# Name: NAME_INCOME_TYPE, dtype: int64
#
# 365243.0    2999
# NaN         1295
# Name: DAYS_EMPLOYED, dtype: int64  # days_employed : 365243 그냥 결측으로 봐도 될듯
#
# 0    4294
# Name: FLAG_WORK_PHONE, dtype: int64
#
# 0    4294
# Name: REG_CITY_NOT_WORK_CITY, dtype: int64
#
# 0    4294
# Name: LIVE_CITY_NOT_WORK_CITY, dtype: int64
#
# NaN    4294
# Name: ORGANIZATION_TYPE, dtype: int64
#
# 0    4294
# Name: FLAG_DOCUMENT_2, dtype: int64
#
# 0    4294
# Name: FLAG_DOCUMENT_4, dtype: int64
#
# NaN    4294
# Name: ADJ_ORGANIZATION_TYPE, dtype: int64        -->

# %% [markdown]
# 백수라 고용일수 없는거니까 0으로 넣기

# %%
adj_df['ADJ_DAYS_EMPLOYED'].value_counts()
# Out:
# -1000.0    2999
#  2.0       1928
#  3.0       1693
#  4.0       1554
#  5.0       1201
#  6.0       1074
#  7.0        829
#  8.0        777
#  9.0        676
#  10.0       534
#  1.0        517
#  11.0       479
#  12.0       365
#  13.0       288
#  14.0       256
#  15.0       252
#  16.0       212
#  17.0       143
#  18.0       122
#  19.0       118
#  20.0       106
#  21.0        95
#  22.0        95
#  23.0        80
#  24.0        59
#  26.0        40
#  27.0        39
#  29.0        39
#  25.0        35
#  33.0        30
#  31.0        29
#  32.0        27
#  35.0        26
#  30.0        26
#  28.0        25
#  34.0        21
#  36.0        16
#  38.0        11
#  40.0         8
#  37.0         8
#  41.0         4
#  39.0         4
#  44.0         2
#  43.0         2
#  42.0         2
#  46.0         2
#  47.0         2
#  45.0         1
# Name: ADJ_DAYS_EMPLOYED, dtype: int64

# %%
adj_df.loc[adj_df['ADJ_DAYS_EMPLOYED'] < 0, 'ADJ_DAYS_EMPLOYED'] = 0

# %% [markdown]
# *2.1 knn방법으로 결측치 대체해보기*

# %%
adj_df.columns
# Out:
# Index(['SK_ID_CURR', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_REALTY',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'FLAG_EMP_PHONE',
#        'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL', 'REGION_RATING_CLIENT',
#        'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START',
#        'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY',
#        'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE', 'FLAG_DOCUMENT_2',
#        'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'CB_SCORE_1', 'CB_SCORE_2',
#        'CB_SCORE_3', 'TARGET', 'ADJ_ORGANIZATION_TYPE',
#        'ADJ_REGION_POPULATION_RELATIVE', 'ADJ_CNT_CHILDREN', 'ADJ_DAYS_BIRTH',
#        'ADJ_DAYS_EMPLOYED', 'ADJ_DAYS_REGISTRATION', 'ADJ_DAYS_ID_PUBLISH'],
#       dtype='object')

# %% [markdown]
# 결측치 대체와 관련없거나 상관성 높은 column drop

# %%
adj_df_v2 = adj_df.drop(columns = ['ORGANIZATION_TYPE','SK_ID_CURR', 'CNT_CHILDREN', 'DAYS_BIRTH','DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH'])

# %%
adj_df_v2.isna().sum()
# object : CODE_GENDER, FLAG_OWN_REALTY, ADJ_ORGANIZATION_TYPE                    
# float  : AMT_CREDIT, CB_SCORE1, CB_SCORE2, CB_SCORE3
# Out:
# NAME_CONTRACT_TYPE                   0
# CODE_GENDER                       7095
# FLAG_OWN_REALTY                   9571
# AMT_INCOME_TOTAL                     0
# AMT_CREDIT                        7300
# NAME_INCOME_TYPE                     0
# NAME_EDUCATION_TYPE                  0
# NAME_FAMILY_STATUS                   1
# NAME_HOUSING_TYPE                    0
# REGION_POPULATION_RELATIVE        7149
# FLAG_EMP_PHONE                       0
# FLAG_WORK_PHONE                      0
# FLAG_PHONE                           0
# FLAG_EMAIL                           0
# REGION_RATING_CLIENT                 0
# WEEKDAY_APPR_PROCESS_START           0
# HOUR_APPR_PROCESS_START              0
# REG_CITY_NOT_LIVE_CITY               0
# REG_CITY_NOT_WORK_CITY               0
# LIVE_CITY_NOT_WORK_CITY              0
# FLAG_DOCUMENT_2                      0
# FLAG_DOCUMENT_3                      0
# FLAG_DOCUMENT_4                      0
# CB_SCORE_1                        6146
# CB_SCORE_2                        8274
# CB_SCORE_3                        7108
# TARGET                               0
# ADJ_ORGANIZATION_TYPE             4294
# ADJ_REGION_POPULATION_RELATIVE    7149
# ADJ_CNT_CHILDREN                     0
# ADJ_DAYS_BIRTH                    4749
# ADJ_DAYS_EMPLOYED                 7149
# ADJ_DAYS_REGISTRATION             9733
# ADJ_DAYS_ID_PUBLISH               4741
# dtype: int64

# %%
adj_df_v2.head(10)
# Out:
#   NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_REALTY  AMT_INCOME_TOTAL  \
# 0         Cash loans           M               Y          202500.0
# 1    Revolving loans         NaN             NaN           67500.0
# 2         Cash loans           M               N          108000.0
# 3         Cash loans           M               N          135000.0
# 4         Cash loans         NaN               Y          202500.0
# 5         Cash loans         NaN               Y          360000.0
# 6         Cash loans           F               Y          225000.0
# 7         Cash loans         NaN               Y          202500.0
# 8         Cash loans         NaN               N          126000.0
# 9         Cash loans           F               N          126000.0
#
#    AMT_CREDIT      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0         NaN               Working  Secondary / secondary special
# 1    135000.0               Working  Secondary / secondary special
# 2    509602.5               Working  Secondary / secondary special
# 3         NaN               Working  Secondary / secondary special
# 4    604152.0               Working  Secondary / secondary special
# 5   1506816.0               Working  Secondary / secondary special
# 6    314055.0  Commercial associate               Higher education
# 7    796396.5               Working               Higher education
# 8    327024.0               Working  Secondary / secondary special
# 9    263686.5             Pensioner  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  REGION_POPULATION_RELATIVE  ...  \
# 0  Single / not married  House / apartment                    0.018801  ...
# 1  Single / not married  House / apartment                         NaN  ...
# 2               Married  House / apartment                    0.018634  ...
# 3               Married  House / apartment                    0.026392  ...
# 4               Married  House / apartment                    0.009175  ...
# 5               Married  House / apartment                    0.010006  ...
# 6               Married  House / apartment                    0.006629  ...
# 7               Married  House / apartment                    0.008019  ...
# 8  Single / not married  House / apartment                         NaN  ...
# 9               Married  House / apartment                    0.009549  ...
#
#    CB_SCORE_2  CB_SCORE_3  TARGET       ADJ_ORGANIZATION_TYPE  \
# 0         NaN   58.349224       1  Business and Self-employed
# 1   57.600542   46.433666       0     Government and Security
# 2   63.496369         NaN       0     Government and Security
# 3   45.996152   68.694333       0  Business and Self-employed
# 4         NaN         NaN       0   Industry and Construction
# 5   47.467175         NaN       0      Logistics and Services
# 6   61.701918         NaN       0  Business and Self-employed
# 7         NaN   59.403718       0   Industry and Construction
# 8         NaN   64.084047       0      Logistics and Services
# 9   69.266436   65.553303       0                         NaN
#
#    ADJ_REGION_POPULATION_RELATIVE ADJ_CNT_CHILDREN  ADJ_DAYS_BIRTH  \
# 0                             1.0                0            25.0
# 1                             NaN                0            51.0
# 2                             2.0                0            34.0
# 3                             3.0                2            30.0
# 4                             4.0                0             NaN
# 5                             5.0                0            49.0
# 6                             6.0                2            28.0
# 7                             7.0                2            43.0
# 8                             NaN                1             NaN
# 9                             8.0                0            58.0
#
#    ADJ_DAYS_EMPLOYED  ADJ_DAYS_REGISTRATION  ADJ_DAYS_ID_PUBLISH
# 0                3.0                   11.0                  7.0
# 1                NaN                   13.0                  8.0
# 2                NaN                    NaN                 12.0
# 3                3.0                    1.0                  NaN
# 4                2.0                    NaN                  2.0
# 5               27.0                   16.0                  6.0
# 6                5.0                    7.0                  NaN
# 7                NaN                   10.0                 12.0
# 8                2.0                   20.0                 17.0
# 9                NaN                    NaN                  NaN
#
# [10 rows x 34 columns]

# %% [markdown]
# # EDA (탐색적 데이터 분석)

# %% [markdown]
# 탐색적 데이터 분석(Exploratory Data Analysis, EDA)은 데이터를 탐색하고 이해하기 위한 과정으로, 주어진 데이터의 특성과 패턴을 파악하는데 사용됩니다. EDA는 데이터 분석의 초기 단계로서 데이터셋의 구조, 변수 간 관계, 이상치 등을 확인하고 가설 설정에 도움을 줍니다. 아래는 탐색적 데이터 분석에 대한 주요 단계와 활용되는 기법들입니다:
#
# 1. 데이터 불러오기: 분석에 필요한 데이터를 적절한 형식으로 불러옵니다. 일반적으로 CSV, Excel, JSON 등 다양한 형식의 파일을 사용합니다.
# 2. 데이터 확인: 데이터셋의 크기와 구조를 파악합니다. head(), tail(), info(), describe() 등의 함수를 사용하여 첫 몇 개의 행이나 열, 변수 정보, 요약 통계량 등을 확인할 수 있습니다.
# 3. 결측치 처리: 결측치(missing values)가 있는지 확인하고 필요에 따라 처리합니다. 결측치를 제거하거나 대체하는 방법으로 처리할 수 있습니다.
# 4. 변수 탐색: 각 변수들의 분포와 특성을 살펴보며 이상치(outlier), 중복값(duplicate value), 범주형 변수의 고유값(unique values) 등을 확인합니다.
# 5. 변수 간 상관 관계: 변수들 사이의 상관 관계를 조사하여 어떤 변수가 다른 변수와 연관되어 있는지 파악합니다. 상관 행렬(correlation matrix), 산점도(scatter plot), 히트맵(heatmap) 등을 사용하여 시각화할 수 있습니다.
# 6. 시각화: 그래프나 차트를 생성하여 데이터 패턴과 인사이트를 시각적으로 파악합니다. 막대 그래프(bar plot), 히스토그램(histogram), 상자 그림(box plot), 선 그래프(line plot), 산점도(scatter plot) 등 다양한 시각화 기법이 활용됩니다.
# 7. 가설 설정 및 검증: EDA 결과를 바탕으로 가설(Hypothesis)을 설정하고 검증하는 단계로 넘어갑니다.
#
#
# EDA는 독립적인 분석 단계로서만 수행되는 것이 아니라 전체 데이터 과학 프로세스에서 반복적으로 활용됩니다.
# EDA 결과에 따라 추가적인 전처리 작업이나 모델링 방법 선택에 영향을 줍니다.
# 탐색적 데이터 분석은 주어진 문제에 대한 인사이트 발견과 잠재된 문제 해결 방법 동일성 발견 및 가정 검증 가능성 제공하여 실전 모델링 단게에서 유용합니다.

# %%
data = df.copy()

# %% [markdown]
# ### 데이터 시각화를 위해 특성변수 설정

# %%
normal_categorical_features = ['NAME_CONTRACT_TYPE','CODE_GENDER','FLAG_OWN_REALTY','CNT_CHILDREN','NAME_INCOME_TYPE','NAME_EDUCATION_TYPE','NAME_FAMILY_STATUS','NAME_HOUSING_TYPE','FLAG_MOBIL','FLAG_EMP_PHONE','FLAG_WORK_PHONE','FLAG_PHONE','FLAG_EMAIL','REGION_RATING_CLIENT',
                               'REG_CITY_NOT_LIVE_CITY','REG_CITY_NOT_WORK_CITY','LIVE_CITY_NOT_WORK_CITY','FLAG_DOCUMENT_2','FLAG_DOCUMENT_3','FLAG_DOCUMENT_4']
long_categorical_features = ['ORGANIZATION_TYPE']
time_features = ['WEEKDAY_APPR_PROCESS_START','HOUR_APPR_PROCESS_START']
key_features = ['SK_ID_CURR']
target_features = ['TARGET']

non_numerical_features = normal_categorical_features +long_categorical_features +time_features + key_features + target_features

numerical_features = [col for col in data.columns if col not in non_numerical_features]
numerical_features
# Out:
# ['AMT_INCOME_TOTAL',
#  'AMT_CREDIT',
#  'REGION_POPULATION_RELATIVE',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'DAYS_REGISTRATION',
#  'DAYS_ID_PUBLISH',
#  'CB_SCORE_1',
#  'CB_SCORE_2',
#  'CB_SCORE_3']

# %% [markdown]
# ### EDA 에 필요한 함수화

# %% [markdown]
# 1. 범주형 변수에 대한 바플랏                 (plot_stats_f)
#    * organization 변수 top 카테고리 플랏     (plot_top_categories)
# 2. 수치형 변수
#    2-1. 단순 & 그룹별 히스토그램 & 박스플랏  (plot_histogram_boxplot)
# 3. 시간 & 요일에 대한 heatmaps (plot_heatmaps)
#   + 결측치 방법론들 판별짓는 EDA
#   + grouping을 위한 EDA

# %%
def plot_stats_v(df, feature_list):
    nrows = len(feature_list)

    for i, feature in enumerate(feature_list):
        fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 5)) # Adjust the size of the graph based on categories

        # Get a list of unique categories sorted by their counts in descending order
        category_order = df[feature].value_counts().index.tolist()

        # Count plot for the feature by TARGET
        count_plot = sns.countplot(x=feature if len(df[feature].unique()) <= 4 else None,
                                   y=None if len(df[feature].unique()) <= 4 else feature,
                                   hue='TARGET', data=df,
                                   order=category_order,
                                   ax=ax[0], palette=['skyblue', 'orange'])

        ax[0].set_title(f'{column}({column_info[column]}) 도수분포표')
        ax[0].set_xlabel(' ')
        ax[0].set_ylabel(' ')

        # Percentage of each category by TARGET
        df_grouped = df.groupby([feature])['TARGET'].value_counts(normalize=True).rename('percentage(%)').reset_index()
        df_grouped['percentage(%)'] = df_grouped['percentage(%)'] * 100

        bar_chart_df = pd.DataFrame(columns=['Category', 'Target_0_Percentage', 'Target_1_Percentage'])
       
        for j, category in enumerate(category_order):
            temp_df = df_grouped[df_grouped[feature] == category]
            target_0_percentage_values = temp_df[temp_df['TARGET']==0]['percentage(%)'].values
            target_1_percentage_values = temp_df[temp_df['TARGET']==1]['percentage(%)'].values
            
            target_0_percentage = target_0_percentage_values[0] if len(target_0_percentage_values) > 0 else 0
            target_1_percentage = target_1_percentage_values[0] if len(target_1_percentage_values) > 0 else 100 - target_0_percentage
            
            bar_chart_df.loc[j] =[category,target_0_percentage,target_1_percentage]
        
        category_order2 = df[feature].value_counts().index.tolist()[::-1]
        
        bar_chart_sorted=bar_chart_df.set_index('Category').loc[category_order].reset_index()
        bar_chart_sorted2=bar_chart_df.set_index('Category').loc[category_order2].reset_index()

        if len(bar_chart_sorted["Category"].unique()) > 4:
            bars = ax[1].barh(bar_chart_sorted2["Category"], bar_chart_sorted2["Target_0_Percentage"], color='skyblue')
            bars2 = ax[1].barh(bar_chart_sorted2["Category"], bar_chart_sorted2["Target_1_Percentage"], left=bar_chart_sorted2["Target_0_Percentage"] ,color='orange')
            # If the categories are binary (0, 1), adjust y-ticks
            if set(bar_chart_sorted2['Category'].unique()).issubset({0, 1}):
                plt.yticks([0, 1])
        else:
            bars = ax[1].bar(bar_chart_sorted["Category"], bar_chart_sorted["Target_0_Percentage"] ,color='skyblue')
            bars2 = ax[1].bar(bar_chart_sorted["Category"], bar_chart_sorted["Target_1_Percentage"], bottom=bar_chart_sorted["Target_0_Percentage"] ,color='orange')
             # If the categories are binary (0, 1), adjust x-ticks
            if set(bar_chart_sorted['Category'].unique()).issubset({0, 1}):
                plt.xticks([0, 1])

        ax[1].set_title(f'{column}({column_info[column]}) 구성 비율')
        ax[1].set_xlabel(' ')
        ax[1].set_ylabel(' ')

    plt.tight_layout(pad=3.03)
    plt.show();

# %%
def plot_histogram_boxplot(df, columns, group_option):
    sns.set_style("whitegrid")  # 그리드를 추가한 흰 배경 스타일
    custom_palette = ["navy", "blue"]
    plt.rcParams['font.family'] = 'NanumGothic'

    for column in columns:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

        # 히스토그램 그리기
        if group_option == True : 
            sns.histplot(data=df, x=column, hue='TARGET', kde=True, ax=axes[0], palette=custom_palette)
        else : 
            sns.histplot(data=df, x=column, kde=True, ax=axes[0], palette=custom_palette)
    
        axes[0].set_title(f'{column}({column_info[column]})의 데이터 분포')
        axes[0].set_xlabel(' ')
        axes[0].set_ylabel('빈도')

        # 상자 그림 그리기
        if group_option == True : 
            sns.boxplot(data=df, x='TARGET', y=column, ax=axes[1], palette=custom_palette)
        else : 
            sns.boxplot(data=df, y=column, ax=axes[1], palette=custom_palette)    
        
        axes[1].set_title(f'연체그룹별 {column}({column_info[column]})의 상자 그림')
        axes[1].set_xlabel(' ')
        axes[1].set_ylabel(' ')

        plt.tight_layout()
        plt.show()

# %%
def plot_top_categories(df, feature, target='TARGET', top_n=20):
    # Get top categories by count
    top_categories_counts = df[feature].value_counts().index[:top_n]

    # Filter dataframe to include only top categories by count
    df_top_categories_counts = df[df[feature].isin(top_categories_counts)]

    fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(15, 5))
    
    # Plot countplot for the feature by TARGET (right)
    sns.countplot(data=df_top_categories_counts,
                  y=feature,
                  hue=target,
                  order=df[feature].value_counts().index[:top_n],
                  ax=axes[0],
                  palette=['skyblue', 'orange'])

    axes[0].set_title(f'Count of {feature} by {target}')
    
    # Calculate and plot percentage of each category by TARGET (left)
    grouped = (df.groupby(feature)[target]
               .value_counts(normalize=True)
               .rename('percentage')
               .mul(100)
               .reset_index()
               .sort_values(by='percentage', ascending=False))

    # Get top categories by ratio
    top_categories_ratio = grouped[grouped[target]==1][feature][:top_n]

    grouped_top_ratio = grouped[grouped[feature].isin(top_categories_ratio)]
    
    sns.barplot(x="percentage", y=feature, hue=target,
                 data=grouped_top_ratio,
                 order=top_categories_ratio,
                 ax=axes[1],
                 palette=['skyblue', 'orange'])

    axes[1].set_title(f'Percentage of {target} in each {feature}')

# %%
def plot_heatmaps(df, day_feature, hour_feature, target='TARGET'):
    # Create a pivot table for the counts heatmap
    pivot_counts = df.pivot_table(index=day_feature,
                                  columns=hour_feature,
                                  values=target,
                                  aggfunc='count')

    # Create a pivot table for the TARGET=1 ratio heatmap
    pivot_ratio = df[df[target] == 1].pivot_table(index=day_feature,
                                                  columns=hour_feature,
                                                  values=target,
                                                  aggfunc='count') / pivot_counts

    # Reorder index (days of week) from Monday to Sunday
    days_order = ['MONDAY', 'TUESDAY', 'WEDNESDAY', 'THURSDAY', 'FRIDAY', 'SATURDAY', 'SUNDAY']
    
    pivot_counts = pivot_counts.reindex(days_order)
    pivot_ratio = pivot_ratio.reindex(days_order)*100

    fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(30, 20))

    # Plot counts heatmap
    sns.heatmap(pivot_counts.fillna(0),
                ax=axes[0],
                cmap="Blues",
                annot=True,
                fmt=".0f")  # Use no decimal places
    
    axes[0].set_title('Counts Heatmap')

     # Plot TARGET=1 ratio heatmap
    sns.heatmap(pivot_ratio.fillna(0),
               ax=axes[1],
               cmap="Blues",
               annot=True,
               fmt=".2f")  # Use two decimal places

    axes[1].set_title('TARGET 1 Ratio Heatmap')
    
    # 요일과 시간에 따른 y 값의 평균 계산
    plotdf = data.groupby([day_feature, hour_feature])[target].mean().unstack()*100

    sns.heatmap(plotdf, cmap='coolwarm', annot=True, fmt=".2f", cbar=True)

    # 축 레이블 설정
    axes[2].set_xlabel('Hour')
    axes[2].set_ylabel('Day of Week')

    # 플롯 출력
    plt.show()

# %% [markdown]
# 실행 code

# %%
plot_stats_v(data, normal_categorical_features)

# %% [markdown]
# 결론 1. flag_mobile 변수 제거 (유효값 1개임)

# %%
data.drop(['FLAG_MOBIL'], inplace = True)

# %%
plot_histogram_boxplot(data, numerical_features, group_option = False)
# Out:
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:13: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=column, kde=True, ax=axes[0], palette=custom_palette)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:13: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=column, kde=True, ax=axes[0], palette=custom_palette)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:13: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=column, kde=True, ax=axes[0], palette=custom_palette)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:13: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=column, kde=True, ax=axes[0], palette=custom_palette)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:29: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# C:\Users\mlosv\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:13: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=column, kde=True, ax=axes[0], palette=custom_palette)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:13: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=column, kde=True, ax=axes[0], palette=custom_palette)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:29: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# C:\Users\mlosv\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:13: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=column, kde=True, ax=axes[0], palette=custom_palette)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:29: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# C:\Users\mlosv\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:13: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=column, kde=True, ax=axes[0], palette=custom_palette)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:13: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=column, kde=True, ax=axes[0], palette=custom_palette)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:13: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=column, kde=True, ax=axes[0], palette=custom_palette)

# %% [markdown]
# 결론 1. 소득금액은 명확한 이상치가 있음 -> 제거

# %%
data['AMT_INCOME_TOTAL'].describe()
# Out:
# count    2.400000e+04
# mean     1.725182e+05
# std      7.604604e+05
# min      2.700000e+04
# 25%      1.125000e+05
# 50%      1.440000e+05
# 75%      2.025000e+05
# max      1.170000e+08
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
data = data[data['AMT_INCOME_TOTAL'] < 1.100000e+08]

# %%
plot_histogram_boxplot(data, numerical_features, group_option = True)
# Out:
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:29: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# C:\Users\mlosv\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:29: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# C:\Users\mlosv\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3021440939.py:29: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# C:\Users\mlosv\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plot_heatmaps(df,'WEEKDAY_APPR_PROCESS_START','HOUR_APPR_PROCESS_START')

# %%
# 그래프 스타일 설정
sns.set_style("whitegrid")  # 그리드를 추가한 흰 배경 스타일
custom_palette = ["navy", "blue"]
plt.rcParams['font.family'] = 'NanumGothic'

for column in numerical_features[1:]:
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

    # 히스토그램 그리기
    sns.histplot(data=data, x=column, kde=False, ax=axes[0], color=custom_palette[0])
    axes[0].set_title(f'{column}({column_info[column]})의 데이터 분포')
    axes[0].set_xlabel(' ')
    axes[0].set_ylabel('빈도')

    # 상자 그림 그리기
    sns.boxplot(data=data, x=column, ax=axes[1], color=custom_palette[1])
    axes[1].set_title(f'{column}({column_info[column]})의 상자 그림')
    axes[1].set_xlabel(' ')

    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3201009943.py:20: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# C:\Users\mlosv\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3201009943.py:20: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# C:\Users\mlosv\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_11132\3201009943.py:20: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()
# C:\Users\mlosv\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from yellowbrick.model_selection import FeatureImportances
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# 모델과 특성 중요도를 계산할 데이터를 입력으로 받아 FeatureImportances plot 그리기
def custom_dependence_plot(feature_importances, data):
    viz = FeatureImportances(feature_importances, labels=data.columns)
    viz.fit(data)
    viz.show()

# %%
# Random Forest Classifier
model = RandomForestClassifier()
model.fit(knn_X_train, y_train)
importances = model.feature_importances_

# %%
importances
# Out:
# array([4.53837188e-03, 1.06044014e-02, 1.01801069e-02, 5.63099117e-02,
#        6.99952960e-02, 1.19907176e-02, 1.33203091e-02, 2.17368428e-02,
#        1.37392163e-02, 6.30356580e-02, 2.44695179e-03, 9.09048878e-03,
#        9.66917289e-03, 4.40877463e-03, 1.24700811e-02, 3.41119820e-02,
#        4.91704488e-02, 6.43316241e-03, 7.67617606e-03, 7.30365786e-03,
#        0.00000000e+00, 8.47381216e-03, 5.73489609e-06, 8.87336549e-02,
#        7.41848444e-02, 7.65507328e-02, 2.84033875e-02, 5.96272473e-02,
#        1.68658858e-02, 6.22548848e-02, 4.95844274e-02, 6.37168817e-02,
#        5.33667782e-02])

# %%
# custom_dependence_plot() 호출
custom_dependence_plot(importances, knn_X_train)
# Out:
# ---------------------------------------------------------------------------
# YellowbrickTypeError                      Traceback (most recent call last)
# Input In [122], in <cell line: 2>()
#       1 # custom_dependence_plot() 호출
# ----> 2 custom_dependence_plot(importances, knn_X_train)
#
# Input In [108], in custom_dependence_plot(feature_importances, data)
#       6 def custom_dependence_plot(feature_importances, data):
# ----> 7     viz = FeatureImportances(feature_importances, labels=data.columns)
#       8     viz.fit(data)
#       9     viz.show()
#
# File ~\anaconda3\lib\site-packages\yellowbrick\model_selection\importances.py:140, in FeatureImportances.__init__(self, estimator, ax, labels, relative, absolute, xlabel, stack, colors, colormap, is_fitted, topn, **kwargs)
#     124 def __init__(
#     125     self,
#     126     estimator,
#    (...)
#     138 ):
#     139     # Initialize the visualizer bases
# --> 140     super(FeatureImportances, self).__init__(
#     141         estimator, ax=ax, is_fitted=is_fitted, **kwargs
#     142     )
#     144     # Data Parameters
#     145     self.labels = labels
#
# File ~\anaconda3\lib\site-packages\yellowbrick\base.py:328, in ModelVisualizer.__init__(self, estimator, ax, fig, is_fitted, **kwargs)
#     326 self.estimator = estimator
#     327 self.is_fitted = is_fitted
# --> 328 self.name = get_model_name(self.estimator)
#     330 # Initialize base classes independently
#     331 Wrapper.__init__(self, self.estimator)
#
# File ~\anaconda3\lib\site-packages\yellowbrick\utils\helpers.py:137, in get_model_name(model)
#     121 """
#     122 Detects the model name for a Scikit-Learn model or pipeline.
#     123
#    (...)
#     134     The name of the model or pipeline.
#     135 """
#     136 if not is_estimator(model):
# --> 137     raise YellowbrickTypeError(
#     138         "Cannot detect the model name for non estimator: '{}'".format(type(model))
#     139     )
#     141 if isinstance(model, Pipeline):
#     142     return get_model_name(model.steps[-1][-1])
#
# YellowbrickTypeError: Cannot detect the model name for non estimator: '<class 'numpy.ndarray'>'

# %%
# PDP 계산
pdp_results = pdp.pdp_isolate(model=model, dataset=X, model_features=feature_names,
                              feature='Feature_Name')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [107], in <cell line: 2>()
#       1 # PDP 계산
# ----> 2 pdp_results = pdp.pdp_isolate(model=model, dataset=X, model_features=feature_names,
#       3                               feature='Feature_Name')
#
# AttributeError: module 'pdp' has no attribute 'pdp_isolate'

# %%
# PDP 그래프 생성
fig, axes = pdp.pdp_plot(pdp_results, 'Feature_Name', plot_lines=True,
                         frac_to_plot=0.5)

# %%
np._version
# Out:
# <module 'numpy._version' from 'C:\\Users\\mlosv\\anaconda3\\lib\\site-packages\\numpy\\_version.py'>

# %%
data['']

# %%
sns.histplot(data=data, x='AMT_INCOME_TOTAL', kde=False, ax=axes[0], color=custom_palette[0])
plt.show()

# %%
column_info[columns]

# %%
column_info['CODE_GENDER']
# Out:
# '성별'

# %%
numeric_columns
# Out:
# Index(['SK_ID_CURR', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'REGION_RATING_CLIENT',
#        'HOUR_APPR_PROCESS_START', 'CB_SCORE_1', 'CB_SCORE_2', 'CB_SCORE_3',
#        'TARGET'],
#       dtype='object')

# %% [markdown]
# 0. 결측데이터간 eda 진행

# %% [markdown]
# 1. KNN 결측치 채우기 진행

# %% [markdown]
# 관련 라이브러리 import

# %%
# !pip install fancyimpute

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, roc_auc_score, mean_squared_error
from fancyimpute import IterativeImputer
# from fancyimpute import KNN, IterativeImputer

# %% [markdown]
# 함수 1 : 범주형 변수 유효값 딕셔너리 생성 함수

# %%
def find_category_mappings(df, variable):
    return {k: i for i, k in enumerate(df[variable].dropna().unique(), 0)}

# %% [markdown]
# 함수 2 : 유효값-숫자로 매칭해, 숫자로 변환해주는 함수

# %%
def integer_encode(df , variable, ordinal_mapping):
    df[variable] = df[variable].map(ordinal_mapping)

# %% [markdown]
# 함수 3 : knn 대체 진행 (범주형까지 적용)

# %%
mm_scaler = MinMaxScaler()
mappin = dict()

# %%
adj_df_v2.isna().sum()
# Out:
# NAME_CONTRACT_TYPE                   0
# CODE_GENDER                       7095
# FLAG_OWN_REALTY                   9571
# AMT_INCOME_TOTAL                     0
# AMT_CREDIT                        7300
# NAME_INCOME_TYPE                     0
# NAME_EDUCATION_TYPE                  0
# NAME_FAMILY_STATUS                   1
# NAME_HOUSING_TYPE                    0
# REGION_POPULATION_RELATIVE        7149
# FLAG_EMP_PHONE                       0
# FLAG_WORK_PHONE                      0
# FLAG_PHONE                           0
# FLAG_EMAIL                           0
# REGION_RATING_CLIENT                 0
# WEEKDAY_APPR_PROCESS_START           0
# HOUR_APPR_PROCESS_START              0
# REG_CITY_NOT_LIVE_CITY               0
# REG_CITY_NOT_WORK_CITY               0
# LIVE_CITY_NOT_WORK_CITY              0
# FLAG_DOCUMENT_2                      0
# FLAG_DOCUMENT_3                      0
# FLAG_DOCUMENT_4                      0
# CB_SCORE_1                        6146
# CB_SCORE_2                        8274
# CB_SCORE_3                        7108
# TARGET                               0
# ADJ_ORGANIZATION_TYPE             4294
# ADJ_REGION_POPULATION_RELATIVE    7149
# ADJ_CNT_CHILDREN                     0
# ADJ_DAYS_BIRTH                    4749
# ADJ_DAYS_EMPLOYED                 7149
# ADJ_DAYS_REGISTRATION             9733
# ADJ_DAYS_ID_PUBLISH               4741
# dtype: int64

# %%
data = adj_df_v2.drop('TARGET', axis=1); y = adj_df_v2['TARGET']

# %%
X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.2)

# %%
# 범주형 변수와 연속형 변수 분리
categorical_cols = data.select_dtypes(include='object').columns.tolist()
continuous_cols = data.select_dtypes(include=['float', 'int']).columns.tolist()

# %%
categorical_cols.append('ADJ_REGION_POPULATION_RELATIVE')

# %%
continuous_cols.remove('ADJ_REGION_POPULATION_RELATIVE')

# %%
# df1 : data 
# cols : categorical columns 
# scaler : MinMax or StandardSclaer
# algorithm : KNN-imputation, MICE-imputation 

def imputation(df1=X_train, df2=X_test, cols=categorical_cols, scaler=mm_scaler, algorithm = KNNImputer()):
    
    #  label 유효값 딕셔너리 생성 
    for variable in cols:
        mappings = find_category_mappings(df1, variable)
        mappin[variable] = mappings

    # label들 숫자로 변환 (결측치는 보존) : train, xtest data 전부 
    for variable in cols:
        integer_encode(df1, variable, mappin[variable])  
        integer_encode(df2, variable, mappin[variable])  

    # 범주형 변수에 대한 min-max scaling 
    sca_xtrain = scaler.fit_transform(df1) 
    imputer = algorithm
    impute_xtrain = imputer.fit_transform(sca_xtrain) # 범주숫자에 대한 스케일링 진행됨 
    
    # test set에 scaling & knn 대체 동일하게 적용
    sca_xtest = scaler.transform(df2)
    impute_xtest = imputer.transform(sca_xtest) 
    
    #  knn
    df1.iloc[:,:] = scaler.inverse_transform(impute_xtrain) 
    df2.iloc[:,:] = scaler.inverse_transform(impute_xtest) 
    
    for i in cols : 
        df1[i] = round(df1[i]).astype('int')
        df2[i] = round(df2[i]).astype('int')
    
    del scaler
#    # Inverse transform
#     for i in cols:
#         inv_map = {v: k for k, v in mappin[i].items()}
#         df[i] = df[i].map(inv_map)
#         df2[i] = df2[i].map(inv_map)
    return df1, df2

# %% [markdown]
# 방법 1. KNN-Imputation

# %%
knn_impute_dat = imputation(X_train, X_test, categorical_cols, mm_scaler, KNNImputer()) # knn-imputer

# %%
import pickle

# 데이터를 저장할 파일 경로
file_path = "C:/Users/mlosv/Downloads/23.08.22 데이터분석경진대회/knn_impute_dat.pickle"

# 데이터를 pickle 파일로 저장
with open(file_path, "wb") as file:
    pickle.dump(knn_impute_dat, file)

# pickle 파일 불러오기
with open(file_path, "rb") as file:
    knn_impute_dat = pickle.load(file)

# %%
knn_X_train, knn_X_test = knn_impute_dat

# %%
knn_X_test
# Out:
#        NAME_CONTRACT_TYPE  CODE_GENDER  FLAG_OWN_REALTY  AMT_INCOME_TOTAL  \
# 2781                    0            1                1          270000.0
# 19670                   0            0                1          135000.0
# 3561                    0            0                1           90000.0
# 19594                   1            1                1           67500.0
# 14041                   0            1                0           90000.0
# ...                   ...          ...              ...               ...
# 9387                    0            1                1           85500.0
# 11295                   0            1                1          180000.0
# 8387                    0            0                0          175500.0
# 9599                    0            1                1          157500.0
# 1845                    1            0                1           90000.0
#
#        AMT_CREDIT  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  \
# 2781    1078200.0                 3                    1                   0
# 19670    894766.5                 0                    0                   0
# 3561     494226.0                 0                    0                   1
# 19594    202500.0                 3                    1                   0
# 14041    480988.8                 0                    1                   1
# ...           ...               ...                  ...                 ...
# 9387     427869.0                 1                    0                   3
# 11295    755190.0                 0                    0                   0
# 8387     706093.2                 3                    0                   1
# 9599     284400.0                 1                    0                   4
# 1845     180000.0                 2                    0                   0
#
#        NAME_HOUSING_TYPE  REGION_POPULATION_RELATIVE  ...  CB_SCORE_1  \
# 2781                   0                    0.018850  ...   55.326949
# 19670                  0                    0.019689  ...   55.927475
# 3561                   0                    0.008575  ...   63.054251
# 19594                  0                    0.026392  ...   33.929064
# 14041                  2                    0.035792  ...   59.889519
# ...                  ...                         ...  ...         ...
# 9387                   0                    0.006671  ...   29.628511
# 11295                  0                    0.008866  ...   37.492430
# 8387                   2                    0.022791  ...   56.333202
# 9599                   0                    0.008230  ...   37.236242
# 1845                   0                    0.004960  ...   76.302626
#
#        CB_SCORE_2  CB_SCORE_3  ADJ_ORGANIZATION_TYPE  \
# 2781    40.083189   55.147518                      1
# 19670   45.222195   57.220567                      0
# 3561    55.129156   63.674671                      8
# 19594   62.295577   58.115250                      5
# 14041   63.812650   74.514029                      0
# ...           ...         ...                    ...
# 9387    69.581909   63.278231                      3
# 11295   52.592022   52.916085                      0
# 8387    50.342632   59.988237                      1
# 9599    70.765548   68.676221                      2
# 1845    59.237023   74.361643                      0
#
#        ADJ_REGION_POPULATION_RELATIVE  ADJ_CNT_CHILDREN  ADJ_DAYS_BIRTH  \
# 2781                               55               0.0            32.4
# 19670                              40               2.0            43.0
# 3561                               76               0.0            38.0
# 19594                              26               1.0            25.0
# 14041                               2               1.0            30.4
# ...                               ...               ...             ...
# 9387                               15               0.0            64.0
# 11295                              66               1.0            34.0
# 8387                               15               0.0            21.0
# 9599                               22               0.0            66.0
# 1845                               68               0.0            37.0
#
#        ADJ_DAYS_EMPLOYED  ADJ_DAYS_REGISTRATION  ADJ_DAYS_ID_PUBLISH
# 2781                 3.6                    5.4                  2.0
# 19670                5.0                   16.0                 12.0
# 3561                 6.0                   22.0                 14.0
# 19594                3.0                   27.0                  3.0
# 14041                2.0                   11.0                  6.2
# ...                  ...                    ...                  ...
# 9387                 0.0                   21.2                 15.0
# 11295                4.0                    4.0                 14.0
# 8387                 5.6                   12.6                  3.0
# 9599                 0.0                   22.0                 13.4
# 1845                 6.0                   12.0                  6.0
#
# [4800 rows x 33 columns]

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(knn_X_train, y_train)
y_pred_knn = knn_model.predict(knn_X_test)

accuracy_knn = accuracy_score(y_test, y_pred_knn)
auc_knn = roc_auc_score(y_test, y_pred_knn)
mse_knn = mean_squared_error(y_test, y_pred_knn)

# %%
print('<KNN-Imputer 결측치 대체 결과>\n',  '정확도:', accuracy_knn, '\n MSE:', mse_knn, '\n AUC:', auc_knn) # auc 가 많이 떨어짐
# Out:
# <KNN-Imputer 결측치 대체 결과>
#  정확도: 0.9164583333333334
#  MSE: 0.08354166666666667
#  AUC: 0.5030291042866434

# %%
# cross_tab = pd.crosstab(y_test, y_pred_knn)

# %%
# cross_tab

# %% [markdown]
# 방법 2. MICE-imputation

# %%
X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.2)

# %%
mice_impute_dat = imputation(X_train, X_test, categorical_cols, mm_scaler, IterativeImputer()) # mice-imputer
# Out:
# C:\Users\mlosv\anaconda3\lib\site-packages\sklearn\impute\_iterative.py:699: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(

# %%
mice_X_train, mice_X_test = mice_impute_dat

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(mice_X_train, y_train)
y_pred_mice = knn_model.predict(mice_X_test)

accuracy_mice = accuracy_score(y_test, y_pred_mice)
auc_mice = roc_auc_score(y_test, y_pred_mice)
mse_mice = mean_squared_error(y_test, y_pred_mice)

# %%
print('<MICE-Imputer 결측치 대체 결과>\n',  '정확도:', accuracy_mice, '\n MSE:', mse_mice, '\n AUC:', auc_mice) # auc 가 많이 떨어짐
# Out:
# <MICE-Imputer 결측치 대체 결과>
#  정확도: 0.91375
#  MSE: 0.08625
#  AUC: 0.5004769207257627

# %% [markdown]
# 만약 범주형 변수를 그대로 라벨 인코딩 한다면?

# %%
X = adj_df_v2.drop('TARGET', axis=1); y = adj_df_v2['TARGET']

# %%
for variable in categorical_cols:
    label_encoder = LabelEncoder()
    X[variable] = label_encoder.fit_transform(X[variable])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
def numeric_imputation(df1=X_train, df2=X_test, algorithm = KNNImputer()):
    
    imputer = algorithm
    df1 = imputer.fit_transform(df1) # 범주숫자에 대한 스케일링 진행됨 
    
    # test set에 scaling & knn 대체 동일하게 적용
    df2 = imputer.transform(df2) 
    
    return df1, df2

# %% [markdown]
# 방법 3. KNN-Imputation (라벨인코딩 후)

# %%
knn_X_train, knn_X_test = numeric_imputation(X_train, X_test, KNNImputer())

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(knn_X_train, y_train)
y_pred_knn = knn_model.predict(knn_X_test)

accuracy_knn = accuracy_score(y_test, y_pred_knn)
auc_knn = roc_auc_score(y_test, y_pred_knn)
mse_knn = mean_squared_error(y_test, y_pred_knn)

print('<KNN-Imputer(only-numeric) 결측치 대체 결과>\n',  '정확도:', accuracy_knn, '\n MSE:', mse_knn, '\n AUC:', auc_knn) # auc 가 많이 떨어짐
# Out:
# <KNN-Imputer(only-numeric) 결측치 대체 결과>
#  정확도: 0.9141666666666667
#  MSE: 0.08583333333333333
#  AUC: 0.5009090909090909

# %% [markdown]
# 방법 4. MICE-Imputation (라벨인코딩 후)

# %%
mice_X_train, mice_X_test = numeric_imputation(X_train, X_test, IterativeImputer())

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(mice_X_train, y_train)
y_pred_mice = knn_model.predict(mice_X_test)

accuracy_mice = accuracy_score(y_test, y_pred_mice)
auc_mice = roc_auc_score(y_test, y_pred_mice)
mse_mice = mean_squared_error(y_test, y_pred_mice)

# %%
print('<MICE-Imputer(only-numeric)| 결측치 대체 결과>\n',  '정확도:', accuracy_mice, '\n MSE:', mse_mice, '\n AUC:', auc_mice) # auc 가 많이 떨어짐
# Out:
# <MICE-Imputer(only-numeric)| 결측치 대체 결과>
#  정확도: 0.9129166666666667
#  MSE: 0.08708333333333333
#  AUC: 0.5013636363636363

# %% [markdown]
# 결측 대체 방법

# %%
na_category_cols = ['CODE_GENDER', 'FLAG_OWN_REALTY', 'NAME_FAMILY_STATUS', 'ADJ_ORGANIZATION_TYPE', 'ADJ_REGION_POPULATION_RELATIVE']

# %%
na_continuous_cols = ['AMT_CREDIT', 'REGION_POPULATION_RELATIVE', 'CB_SCORE_1', 'CB_SCORE_2', 'CB_SCORE_3',  'ADJ_DAYS_BIRTH', 'ADJ_DAYS_EMPLOYED', 'ADJ_DAYS_REGISTRATION', 'ADJ_DAYS_ID_PUBLISH']

# %%
X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.2)
knn_X_train, knn_X_test = knn_impute_dat
mice_X_train, mice_X_test = mice_impute_dat

# %%
import matplotlib.pyplot as plt

# 연속형 변수의 히스토그램 그리기
def plot_continuous_histogram(data1, data2, data3, column):
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    
    axes[0].hist(data1[column], bins=20)
    axes[0].set_title('Original Data - Histogram of {}'.format(column))
    axes[0].set_xlabel(column)
    axes[0].set_ylabel('Frequency')
    
    axes[1].hist(data2[column], bins=20)
    axes[1].set_title('KNN-imputation Data - Histogram of {}'.format(column))
    axes[1].set_xlabel(column)
    axes[1].set_ylabel('Frequency')
    
    
    axes[2].hist(data3[column], bins=20)
    axes[2].set_title('MICE-imputation Data - Histogram of {}'.format(column))
    axes[2].set_xlabel(column)
    axes[2].set_ylabel('Frequency')
    
    plt.tight_layout()
    plt.show()

# %%
for col in na_continuous_cols : 
    plot_continuous_histogram(X_train, knn_X_train, mice_X_train, col)

# %%
# 범주형 변수의 바 그래프 그리기
def plot_categorical_barplot(data1, data2, data3, column):
    fig, ax = plt.subplots(1, 3, figsize=(18, 6))
    
    value_counts_data1 = data1[column].value_counts(normalize = True)
    ax[0].bar(value_counts_data1.index.tolist(), value_counts_data1.values.tolist())
    
    ax[0].set_title('Original Data - Bar Plot of {}'.format(column))
    ax[0].set_xlabel(column)
    ax[0].set_ylabel('Count')
     
    value_counts_data2 = data2[column].value_counts(normalize = True)
    ax[1].bar(value_counts_data2.index.tolist(), value_counts_data2.values.tolist())
     
    ax[1].set_title('KNN-imputation Data - Bar Plot of {}'.format(column))
    ax[1].set_xlabel(column)
    ax[1].set_ylabel('Count')

    value_counts_data3 = data3[column].value_counts(normalize = True)
    ax[2].bar(value_counts_data3.index.tolist(), value_counts_data3.values.tolist())
     
    ax[2].set_title('MICE-imputation Data - Bar Plot of {}'.format(column))
    ax[2].set_xlabel(column)
    ax[2].set_ylabel('Count')
    
    plt.tight_layout()
    plt.show()

# %%
for col in na_category_cols : 
    plot_categorical_barplot(X_train, knn_X_train, mice_X_train, col)

# %% [markdown]
# # 파생변수 생성

# %%
# 결측치가 있는 컬럼들 찾기
columns_with_missing_values = data.columns[data.isnull().any()].tolist()

# 각 결측치가 있는 컬럼에 대해 결측치 여부를 나타내는 새로운 컬럼 생성 (knn, mice impute 데이터에)
for column in columns_with_missing_values:
    new_column_name = column + '_missing'
    mice_X_train[new_column_name] = data[column].isnull().astype(int)
    knn_X_train[new_column_name] = data[column].isnull().astype(int)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# KNN-imputation data 랜덤 포레스트 모델 생성 및 학습
rf_model = RandomForestClassifier()
rf_model.fit(knn_X_train, y_train)

# KNN-imputation data 변수 중요도 계산
rf_feature_importances = rf_model.feature_importances_

# MICE-imputation data 랜덤 포레스트 모델 생성 및 학습
rf_model = RandomForestClassifier()
rf_model.fit(mice_X_train, y_train)

# MICE-imputation data 변수 중요도 계산
mice_feature_importances = rf_model.feature_importances_

# %%
# 변수 중요도 시각화
def plot_feature_importance(feature_names, rf_feature_importances, mice_feature_importances):
    sorted_idx = np.argsort(rf_feature_importances)
    pos = np.arange(sorted_idx.shape[0]) + .5

    fig, ax = plt.subplots(1, 2, figsize=(20, 10))
    ax[0].barh(pos, rf_feature_importances[sorted_idx], align='center')
    ax[0].set_yticks(pos)
    ax[0].set_yticklabels(np.array(feature_names)[sorted_idx])
    ax[0].set_xlabel('Kre Importance')
    ax[0].set_title('Variable Importance')
    
    sorted_idx = np.argsort(mice_feature_importances)
    pos = np.arange(sorted_idx.shape[0]) + .5

    ax[1].barh(pos, mice_feature_importances[sorted_idx], align='center')
    ax[1].set_yticks(pos)
    ax[1].set_yticklabels(np.array(feature_names)[sorted_idx])
    ax[1].set_xlabel('Kre Importance')
    ax[1].set_title('Variable Importance')
    
    plt.tight_layout()
    plt.show()

# %%
column_names = knn_X_train.columns

# %%
plot_feature_importance(column_names, rf_feature_importances, mice_feature_importances)

# %%
tmp_cols = ['CB_SCORE_1', 'CB_SCORE_2', 'CB_SCORE_3', 'AMT_CREDIT'
            , 'ADJ_DAYS_BIRTH', 'ADJ_DAYS_REGISTRATION', 'REGION_POPULATION_RELATIVE']

# %%
mice_X_train, mice_X_test = mice_impute_dat

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(mice_X_train[tmp_cols], y_train)
y_pred_mice = knn_model.predict(mice_X_test[tmp_cols])

accuracy_mice = accuracy_score(y_test, y_pred_mice)
auc_mice = roc_auc_score(y_test, y_pred_mice)
mse_mice = mean_squared_error(y_test, y_pred_mice)

# %%
print('<MICE-Imputer 결측치 대체 결과>\n',  '정확도:', accuracy_mice, '\n MSE:', mse_mice, '\n AUC:', auc_mice) # auc 가 많이 떨어짐
# Out:
# <MICE-Imputer 결측치 대체 결과>
#  정확도: 0.9077083333333333
#  MSE: 0.09229166666666666
#  AUC: 0.5013404588835794

# %%
rf_model = RandomForestClassifier()
rf_model.fit(mice_X_train[tmp_cols], y_train)
y_pred_mice = rf_model.predict(mice_X_test[tmp_cols])

accuracy_mice = accuracy_score(y_test, y_pred_mice)
auc_mice = roc_auc_score(y_test, y_pred_mice)
mse_mice = mean_squared_error(y_test, y_pred_mice)

# %%
print('<MICE-Imputer 결측치 대체 결과>\n',  '정확도:', accuracy_mice, '\n MSE:', mse_mice, '\n AUC:', auc_mice) # auc 가 많이 떨어짐
# Out:
# <MICE-Imputer 결측치 대체 결과>
#  정확도: 0.91125
#  MSE: 0.08875
#  AUC: 0.5011709601873536

# %% [markdown]
# 방법 5. GAIN 알고리즘

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.losses import BinaryCrossentropy, MeanSquaredError

# %%
# X와 y 분리
X = adj_df_v2.drop('TARGET', axis=1); y = adj_df_v2['TARGET']

# 연속형 변수와 범주형 변수 분리 (예시)
categorical_cols = X.select_dtypes(include='object').columns.tolist()
continuous_cols = X.select_dtypes(include=['float64', 'int64']).columns.tolist()

X_continuous = X[continuous_cols]
X_categorical = X[categorical_cols]

# %%
# 데이터 스케일링 (연속형 변수)
scaler_continuous = MinMaxScaler()
X_continuous_scaled = scaler_continuous.fit_transform(X_continuous)

# %%
# 레이블 인코딩 (범주형 변수)
encoder_categoricals = {}
# X_categorical_encoded = {}
for col in categorical_cols:
    encoder_categoricals[col] = LabelEncoder()
    X_categorical[col] = encoder_categoricals[col].fit_transform(X_categorical[col])
# Out:
# C:\Users\mlosv\AppData\Local\Temp\ipykernel_23284\3559380252.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_categorical[col] = encoder_categoricals[col].fit_transform(X_categorical[col])

# %%
# 결합된 입력 데이터 생성 및 훈련/테스트 세트 분할 
X_combined_scaled_encoded= pd.concat([pd.DataFrame(X_continuous_scaled, columns=continuous_cols),
                                      pd.DataFrame(X_categorical, columns=categorical_cols)], axis=1)

# %%
X_train, X_test, y_train, y_test=train_test_split(X_combined_scaled_encoded,y,test_size=0.2)
input_dim=X_combined_scaled_encoded.shape[1]

# %%
# Generator 모델 정의
def build_generator(input_dim):
    inputs=Input(shape=(input_dim,))
    x=Dense(128,'relu')(inputs)
    x=Dense(128,'relu')(x)
    outputs=Dense(input_dim)(x)
    generator_model=Model(inputs,outputs=outputs,name='generator')
    return generator_model

# %%
# Discriminator 모델 정의 
def build_discriminator(input_dim):
    inputs=tf.keras.Input(shape=(input_dim,))
    x=tf.keras.layers.Dense(128,'relu')(inputs)
    x=tf.keras.layers.Dense(128,'relu')(x)
    outputs=tf.keras.layers.Dense(1)(x)
 
    discriminator_model=Model(inputs,outputs=outputs,name='discriminator')
    
    return discriminator_model

# %%
# GAIN 모델 정의 및 컴파일 
def build_gain(generator_model,discriminator_model):
    input_real_X_d=gain.generator.input_real_X_dscrmtrmstcs=input_size_real_X_dscrmtrmstcs=[None,X_train.shape[1]]
    input_fake_X_d=gain.generator.input_fake_X_dscrmtrmstcs=input_size_fake_X_dscrmtrmstcs=[None,X_train.shape[1]]
    gain.generator.inputs=input_real_X_d,gain.generator.inputs=input_fake_X_d

    real_output_D=gain.discriminator(real_input_D) 
    fake_output_D=gain.discriminator(fake_input_D)

    gain.discriminator.inputs=fake_input_D,gain.discriminator.inputs=fake_output_G

    # 손실 함수 설정 
    loss_GAN=GAIN_loss(y_true=y_true,y_pred=y_pred,marginal_posterior=marginal_posterior,sampling_posterior=sampling_posterior,lamda=lambda_val,sample_size=batch_size,n_features=n_features,n_labels=n_labels)
    loss_generator=GAIN_loss_generator(y_true=y_true,y_pred=y_pred,marginal_posterior=marginal_posterior,sampling_posterior=sampling_posterior,lamda=lambda_val,sample_size=batch_size,n_features=n_features,n_labels=n_labels)

    loss_discriminator=GAIN_loss_discriminator(y_true=y_true,y_pred=y_pred,marginal_prior=marginal_prior,marginal_missing=marginal_missing,
                                              marginal_generated=marginal_generated,lamda=lambda_val,sample_size=batch_size,
                                              n_features=n_features,n_labels=n_labels)

    gain.compile(loss={'discriminator':loss_discriminator,'generator':loss_generator},optimizer='adam')

    return gain

# %%
 # GAIN 알고리즘 학습 

generator_model=build_generator(input_dim)
discriminator_model=build_discriminator(input_dim)

# %%
gan_input_real_samples_placeholder=tf.data.Dataset.from_tensor_slices(real_imputed_samples).batch(batch_sz).repeat().make_one_shot_iterator().get_next()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [180], in <cell line: 1>()
# ----> 1 gan_input_real_samples_placeholder=tf.data.Dataset.from_tensor_slices(real_imputed_samples).batch(batch_sz).repeat().make_one_shot_iterator().get_next()
#
# NameError: name 'real_imputed_samples' is not defined

# %%
def build_gan(generator_model, discriminator_model):
    gan_input = Input(shape=(input_dim,))
    generated_data = generator_model(gan_input)
    gan_output = discriminator_model(generated_data)

    gan = Model(gan_input, gan_output)
    
    return gan

gan = build_gan(generator_model, discriminator_model)

# %%
# 손실 함수 설정
loss_discriminator = tf.keras.losses.BinaryCrossentropy(from_logits=True)
loss_generator = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# 옵티마이저 설정
optimizer_discriminator = tf.keras.optimizers.Adam(learning_rate=0.001)
optimizer_generator = tf.keras.optimizers.Adam(learning_rate=0.001)

# 컴파일
gan.compile(optimizer=optimizer_generator, loss=loss_discriminator)

# %%
# GAIN 알고리즘 학습 
# gan.build_gain(build_generator(input_dim),build__discriminator(input_dim))

gan.fit({'generator':np.concatenate([real_imputed_samples,fake_samples]),'discriminator':np.concatenate([real_samples,np.repeat(np.nan,batch_sz)])},
         {'generator':np.concatenate([real_samples,np.repeat(np.nan,batch_sz)]),'discriminator':[np.ones((batch_sz*2)),np.zeros(batch_sz)]},
         epochs=num_epochs,batch_siz=batch_sz)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [160], in <cell line: 4>()
#       1 # GAIN 알고리즘 학습
#       2 # gan.build_gain(build_generator(input_dim),build__discriminator(input_dim))
# ----> 4 gan.fit({'generator':np.concatenate([real_imputed_samples,fake_samples]),'discriminator':np.concatenate([real_samples,np.repeat(np.nan,batch_sz)])},
#       5          {'generator':np.concatenate([real_samples,np.repeat(np.nan,batch_sz)]),'discriminator':[np.ones((batch_sz*2)),np.zeros(batch_sz)]},
#       6          epochs=num_epochs,batch_siz=batch_sz)
#
# NameError: name 'real_imputed_samples' is not defined

# %% [markdown]
# 결측있는 변수를 제거해본다면 ?

# %%
data = adj_df_v2.drop('TARGET', axis=1); y = adj_df_v2['TARGET']

# %%
X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.2)

# %%
X_train.isna().sum()
# Out:
# NAME_CONTRACT_TYPE                   0
# CODE_GENDER                       5697
# FLAG_OWN_REALTY                   7647
# AMT_INCOME_TOTAL                     0
# AMT_CREDIT                        5850
# NAME_INCOME_TYPE                     0
# NAME_EDUCATION_TYPE                  0
# NAME_FAMILY_STATUS                   1
# NAME_HOUSING_TYPE                    0
# FLAG_EMP_PHONE                       0
# FLAG_WORK_PHONE                      0
# FLAG_PHONE                           0
# FLAG_EMAIL                           0
# REGION_RATING_CLIENT                 0
# WEEKDAY_APPR_PROCESS_START           0
# HOUR_APPR_PROCESS_START              0
# REG_CITY_NOT_LIVE_CITY               0
# REG_CITY_NOT_WORK_CITY               0
# LIVE_CITY_NOT_WORK_CITY              0
# FLAG_DOCUMENT_2                      0
# FLAG_DOCUMENT_3                      0
# FLAG_DOCUMENT_4                      0
# CB_SCORE_1                        4915
# CB_SCORE_2                        6540
# CB_SCORE_3                        5745
# ADJ_ORGANIZATION_TYPE             3440
# ADJ_REGION_POPULATION_RELATIVE    5709
# ADJ_CNT_CHILDREN                     0
# ADJ_DAYS_BIRTH                    3814
# ADJ_DAYS_EMPLOYED                 5747
# ADJ_DAYS_REGISTRATION             7805
# ADJ_DAYS_ID_PUBLISH               3774
# dtype: int64

# %%
categorical_cols
# Out:
# Index(['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_REALTY',
#        'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS',
#        'NAME_HOUSING_TYPE', 'WEEKDAY_APPR_PROCESS_START',
#        'ADJ_ORGANIZATION_TYPE'],
#       dtype='object')

# %%
X_train.drop(['CODE_GENDER', 'FLAG_OWN_REALTY', ])

# %%
mice_X_train, mice_X_test = numeric_imputation(X_train, X_test, IterativeImputer())

# %%
knn_model = KNeighborsClassifier()
knn_model.fit(mice_X_train, y_train)
y_pred_mice = knn_model.predict(mice_X_test)

accuracy_mice = accuracy_score(y_test, y_pred_mice)
auc_mice = roc_auc_score(y_test, y_pred_mice)
mse_mice = mean_squared_error(y_test, y_pred_mice)

# %%
print('<MICE-Imputer(only-numeric)| 결측치 대체 결과>\n',  '정확도:', accuracy_mice, '\n MSE:', mse_mice, '\n AUC:', auc_mice) # auc 가 많이 떨어짐
# Out:
# <MICE-Imputer(only-numeric)| 결측치 대체 결과>
#  정확도: 0.91125
#  MSE: 0.08875
#  AUC: 0.5042410291984613

# %%
import missingno as msno

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_REALTY',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'FLAG_MOBIL', 'FLAG_EMP_PHONE',
#        'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL', 'REGION_RATING_CLIENT',
#        'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START',
#        'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY',
#        'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE', 'FLAG_DOCUMENT_2',
#        'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'CB_SCORE_1', 'CB_SCORE_2',
#        'CB_SCORE_3', 'TARGET'],
#       dtype='object')

# %%
adj_df.columns
# Out:
# Index(['SK_ID_CURR', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_REALTY',
#        'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'FLAG_EMP_PHONE',
#        'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_EMAIL', 'REGION_RATING_CLIENT',
#        'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START',
#        'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY',
#        'LIVE_CITY_NOT_WORK_CITY', 'ORGANIZATION_TYPE', 'FLAG_DOCUMENT_2',
#        'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'CB_SCORE_1', 'CB_SCORE_2',
#        'CB_SCORE_3', 'TARGET', 'ADJ_ORGANIZATION_TYPE',
#        'ADJ_REGION_POPULATION_RELATIVE', 'ADJ_CNT_CHILDREN', 'ADJ_DAYS_BIRTH',
#        'ADJ_DAYS_EMPLOYED', 'ADJ_DAYS_REGISTRATION', 'ADJ_DAYS_ID_PUBLISH'],
#       dtype='object')

# %%
msno.bar(adj_df_v2)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(adj_df_v2)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(adj_df_v2.sample(100))
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(adj_df_v2)
# Out:
# <AxesSubplot:>

# %%
msno.dendrogram(adj_df_v2)
# Out:
# <AxesSubplot:>

# %%
adj_df['CODE_GENDER'].value_counts(dropna = False )
# Out:
# F      11211
# NaN     7095
# M       5694
# Name: CODE_GENDER, dtype: int64

# %%
aj

# %%
pd.get_dummies(adj_df['CODE_GENDER'], prefix='CODE_GENDER')
# Out:
#        CODE_GENDER_F  CODE_GENDER_M
# 0                  0              1
# 1                  0              0
# 2                  0              1
# 3                  0              1
# 4                  0              0
# ...              ...            ...
# 23995              0              0
# 23996              0              0
# 23997              0              1
# 23998              0              0
# 23999              0              0
#
# [24000 rows x 2 columns]

# %%
for col in df.columns :
    print(col + ',' + column_info[col] + ':' + str(df[col].isna().sum()))
# Out:
# SK_ID_CURR,대출식별번호:0
# NAME_CONTRACT_TYPE,계약유형:0
# CODE_GENDER,성별:7094
# FLAG_OWN_REALTY,자가부동산보유여부:9571
# CNT_CHILDREN,자녀수:0
# AMT_INCOME_TOTAL,소득금액(USD):0
# AMT_CREDIT,신용대출금액(USD):7300
# NAME_INCOME_TYPE,소득유형:0
# NAME_EDUCATION_TYPE,학력:0
# NAME_FAMILY_STATUS,결혼상태:0
# NAME_HOUSING_TYPE,주거형태:0
# REGION_POPULATION_RELATIVE,거주지역의표준화된인구:7149
# DAYS_BIRTH,대출신청시점에서의일단위나이(기준시점대비상대적인시간):4749
# DAYS_EMPLOYED,대출신청시점에서의고객의근무일수(기준시점대비상대적인시간):7149
# DAYS_REGISTRATION,대출신청이전에고객이등록정보를변경한시점사이의일수(기준시점대비상대적인시간):9733
# DAYS_ID_PUBLISH,대출신청이전에고객이신분증을변경한시점사이의일수(기준시점대비상대적인시간):4741
# FLAG_MOBIL,휴대폰번호등록여부:0
# FLAG_EMP_PHONE,고용주연락처등록여부:0
# FLAG_WORK_PHONE,직장전화번호등록여부:0
# FLAG_PHONE,집전화번호등록여부:0
# FLAG_EMAIL,이메일주소등록여부:0
# REGION_RATING_CLIENT,거주지등급:0
# WEEKDAY_APPR_PROCESS_START,대출신청요일:0
# HOUR_APPR_PROCESS_START,대출신청시간대:0
# REG_CITY_NOT_LIVE_CITY,고객의등록지주소와실거주지일치여부:0
# REG_CITY_NOT_WORK_CITY,고객의등록지주소와직장주소일치여부:0
# LIVE_CITY_NOT_WORK_CITY,고객의실거주지와직장주소일치여부:0
# ORGANIZATION_TYPE,근무회사유형:0
# FLAG_DOCUMENT_2,문서2제공여부:0
# FLAG_DOCUMENT_3,문서3제공여부:0
# FLAG_DOCUMENT_4,문서4제공여부:0
# CB_SCORE_1,신용점수1:6146
# CB_SCORE_2,신용점수2:8274
# CB_SCORE_3,신용점수3:7108
# TARGET,연체여부:0

# %%
from impyute.imputation.cs import mice

# start the MICE training
imputed_training=mice(adj_df_v2.values)
# Out:
# ---------------------------------------------------------------------------
# BadInputError                             Traceback (most recent call last)
# Input In [124], in <cell line: 4>()
#       1 from impyute.imputation.cs import mice
#       3 # start the MICE training
# ----> 4 imputed_training=mice(adj_df_v2.values)
#
# File ~\anaconda3\lib\site-packages\impyute\util\preprocess.py:55, in preprocess.<locals>.wrapper(*args, **kwargs)
#      53     return pd_DataFrame(fn(*args, **kwargs))
#      54 else:
# ---> 55     return fn(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\impyute\util\checks.py:33, in checks.<locals>.wrapper(*args, **kwargs)
#      31     raise BadInputError("Not a np.ndarray.")
#      32 elif not _dtype_float(data):
# ---> 33     raise BadInputError("Data is not float.")
#      34 elif not _nan_exists(data):
#      35     raise BadInputError("No NaN's in given data")
#
# BadInputError: Data is not float.

# %%
from sklearn.impute import KNNImputer

#임퓨터 선언(5개의 평균으로 계산하겠다)
imputer=KNNImputer(n_neighbors=5)

# %%
adj_df_v2[categorical_cols]
# Out:
#       NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_REALTY      NAME_INCOME_TYPE  \
# 0             Cash loans           M               Y               Working
# 1        Revolving loans         NaN             NaN               Working
# 2             Cash loans           M               N               Working
# 3             Cash loans           M               N               Working
# 4             Cash loans         NaN               Y               Working
# ...                  ...         ...             ...                   ...
# 23995         Cash loans         NaN             NaN             Pensioner
# 23996         Cash loans         NaN               N               Working
# 23997         Cash loans           M               Y               Working
# 23998         Cash loans         NaN             NaN               Working
# 23999         Cash loans         NaN               N  Commercial associate
#
#                  NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# 0      Secondary / secondary special  Single / not married  House / apartment
# 1      Secondary / secondary special  Single / not married  House / apartment
# 2      Secondary / secondary special               Married  House / apartment
# 3      Secondary / secondary special               Married  House / apartment
# 4      Secondary / secondary special               Married  House / apartment
# ...                              ...                   ...                ...
# 23995               Higher education               Married  House / apartment
# 23996  Secondary / secondary special               Married  House / apartment
# 23997               Higher education               Married  House / apartment
# 23998               Higher education  Single / not married  House / apartment
# 23999  Secondary / secondary special               Married   Rented apartment
#
#       WEEKDAY_APPR_PROCESS_START       ADJ_ORGANIZATION_TYPE
# 0                      WEDNESDAY  Business and Self-employed
# 1                         MONDAY     Government and Security
# 2                       THURSDAY     Government and Security
# 3                       THURSDAY  Business and Self-employed
# 4                         MONDAY   Industry and Construction
# ...                          ...                         ...
# 23995                     SUNDAY                         NaN
# 23996                     MONDAY  Business and Self-employed
# 23997                     FRIDAY  Business and Self-employed
# 23998                     FRIDAY                   Education
# 23999                     MONDAY  Business and Self-employed
#
# [24000 rows x 9 columns]

# %%
adj_df_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24000 entries, 0 to 23999
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   NAME_CONTRACT_TYPE              24000 non-null  object
#  1   CODE_GENDER                     16905 non-null  object
#  2   FLAG_OWN_REALTY                 14429 non-null  object
#  3   AMT_INCOME_TOTAL                24000 non-null  float64
#  4   AMT_CREDIT                      16700 non-null  float64
#  5   NAME_INCOME_TYPE                24000 non-null  object
#  6   NAME_EDUCATION_TYPE             24000 non-null  object
#  7   NAME_FAMILY_STATUS              23999 non-null  object
#  8   NAME_HOUSING_TYPE               24000 non-null  object
#  9   FLAG_EMP_PHONE                  24000 non-null  int64
#  10  FLAG_WORK_PHONE                 24000 non-null  int64
#  11  FLAG_PHONE                      24000 non-null  int64
#  12  FLAG_EMAIL                      24000 non-null  int64
#  13  REGION_RATING_CLIENT            24000 non-null  int64
#  14  WEEKDAY_APPR_PROCESS_START      24000 non-null  object
#  15  HOUR_APPR_PROCESS_START         24000 non-null  int64
#  16  REG_CITY_NOT_LIVE_CITY          24000 non-null  int64
#  17  REG_CITY_NOT_WORK_CITY          24000 non-null  int64
#  18  LIVE_CITY_NOT_WORK_CITY         24000 non-null  int64
#  19  FLAG_DOCUMENT_2                 24000 non-null  int64
#  20  FLAG_DOCUMENT_3                 24000 non-null  int64
#  21  FLAG_DOCUMENT_4                 24000 non-null  int64
#  22  CB_SCORE_1                      17854 non-null  float64
#  23  CB_SCORE_2                      15726 non-null  float64
#  24  CB_SCORE_3                      16892 non-null  float64
#  25  TARGET                          24000 non-null  int64
#  26  ADJ_ORGANIZATION_TYPE           19706 non-null  object
#  27  ADJ_REGION_POPULATION_RELATIVE  16851 non-null  float64
#  28  ADJ_CNT_CHILDREN                24000 non-null  int64
#  29  ADJ_DAYS_BIRTH                  19251 non-null  float64
#  30  ADJ_DAYS_EMPLOYED               16851 non-null  float64
#  31  ADJ_DAYS_REGISTRATION           14267 non-null  float64
#  32  ADJ_DAYS_ID_PUBLISH             19259 non-null  float64
# dtypes: float64(10), int64(14), object(9)
# memory usage: 6.0+ MB

# %%
#임퓨터를 사용하여 filled_train으로 저장 이후 같은 임퓨터를 사용할때는 imputer.transform()으로 사용하면됨
filled_train=imputer.fit_transform(adj_df_v2)

# %%
#사용하면 array값으로 나오기때문에 dataframe으로 바꿔주고 컬럼을가져옴
filled_train=pd.DataFrame(filled_train, columns=train.columns)
